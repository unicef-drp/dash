# %%
import json

# Load the indicator buttons JSON
with open('indicator_buttons.json', 'r') as file:
    indicator_buttons = json.load(file)

# %%
indicator_buttons
# Out:
# {'DM_POP_TOT_AGE': 'Total population',
#  'DM_ESTAT_POP': 'Total population',
#  'DM_NSO_POP': 'Total population',
#  'DM_COMP_POP': 'Total population',
#  'DM_CHLD_POP': 'Child population',
#  'DM_YOUNG_NSO': nan,
#  'DM_CHLD_YOUNG_COMP_POP': nan,
#  'DM_CHLD_YOUNG_POP': nan,
#  'DM_CHLD_POP_PT': 'Children as a share of the total population',
#  'DM_FRATE_TOT': 'Total fertility rate',
#  'DM_BRTS': 'Number of births',
#  'DM_SP_POP_BRTH_MF': nan,
#  'DM_LIFE_EXP': nan,
#  'DM_CHLD_TWO_PRNT': nan,
#  'DM_POP_NETM': 'Net migration',
#  'DM_POP_URBN': nan,
#  'DM_CHLD_NSO': nan,
#  'FT_WHS_PBR': nan,
#  'MT_SP_DYN_CDRT_IN': nan,
#  'DM_ADOL_POP': nan,
#  'DM_TOT_POP_PROSP': nan,
#  'DM_ADOL_YOUTH_POP': nan,
#  'DM_ADULT_YOUTH_POP': nan,
#  'DM_REPD_AGE_POP': nan,
#  'MG_INTNL_MG_CNTRY_DEST_PS': nan,
#  'MG_INTNL_MG_CNTRY_DEST_RT': nan,
#  'EC_NY_GDP_PCAP_KD_ZG': nan,
#  'EC_NY_GNP_PCAP_CD': 'GNI per capita, Atlas method',
#  'EC_GR_G14_GDP': nan,
#  'EC_TEC_GRL_GOV_EXP': 'Total general government expenditure',
#  'EC_TOT_PUB_EXP_GDP': nan,
#  'EC_TOT_PUB_EXP_TOT': nan,
#  'EC_GC_DOD_TOTL_GD_ZS': nan,
#  'EC_EAP_RT': 'Labour force participation rate',
#  'EC_SL_UEM_TOTL_ZS': 'Unemployment, modelled ILO estimate (SDG 8.5.2)',
#  'EC_SL_UEM_TOTL_NE_ZS': nan,
#  'EC_YOUTH_UNE_RT': nan,
#  'EC_SI_POV_GINI': 'Gini Index',
#  'PV_GINI_COEF': 'Gini Index',
#  'EC_HDI': 'Human Development Index',
#  'FP_CPI_TOTL_ZG': 'Inflation',
#  'EC_NY_GDP_PCAP_PP_CD': 'GDP per capita, PPP',
#  'NY_GDP_MKTP_KN': nan,
#  'NY_GDP_MKTP_CN': nan,
#  'NY_GDP_PCAP_CN': nan,
#  'EC_TEC_SSF_EXP': nan,
#  'SI_DST_10TH_10': nan,
#  'SI_DST_FRST_10': nan,
#  'EC_NE_DAB_TOTL_ZS': nan,
#  'EC_TEC_CNT_GOV_EXP': nan,
#  'EC_TEC_STA_GOV_EXP': nan,
#  'EC_TEC_LOC_GOV_EXP': nan,
#  'EC_NY_GNP_ATLS_CD': nan,
#  'EC_IQ_CPA_GNDR_XQ': nan,
#  'EC_SIGI': nan,
#  'EC_GNI_PCAP_PPP': nan,
#  'EC_FB_BNK_ACCSS': nan,
#  'SL_DOM_TSPD': nan,
#  'SG_GEN_PARL': nan,
#  'EC_INACT_RT': nan,
#  'EC_YOUTH_INACT_RT': nan,
#  'EC_GEN_PAY_GAP': nan,
#  'EC_GEN_CONF_JUD': nan,
#  'EC_HCI_OVRL': nan,
#  'EC_MIN_WAGE': nan,
#  'CR_UN_CHLD_SALE': nan,
#  'CR_UN_RIGHTS_DISAB': nan,
#  'CR_UN_CHLD_ARMED': nan,
#  'CR_UN_CHLD_COMM': nan,
#  'PP_SG_NHR_IMPLN': 'Status of National Human Rights Institutions (SDG 16.a.1)',
#  'PP_SG_NHR_INTEXSTN': nan,
#  'PP_SG_NHR_NOSTUSN': nan,
#  'PP_SG_NHR_NOAPPLN': nan,
#  'CR_VC_VOV_GDSD': nan,
#  'CR_VC_VOV_GDSD_DISHEA_PD': nan,
#  'CR_UN_CHLD_RIGHTS': nan,
#  'EDU_FIN_EXP_PT_GDP': 'Government expenditure on education',
#  'EC_SP_GOV_EXP_GDP': 'General government expenditure on social protection',
#  'EC_SP_GOV_EXP_TOT': nan,
#  'EC_EXP_FAM_CHLD_GDP': nan,
#  'EC_EXP_FAM_CHLD_EXP': 'Expenditure on family-children benefits',
#  'EC_EXP_FAM_KIND_GDP': nan,
#  'EC_EXP_FAM_LUMP_CASH_GDP': nan,
#  'EC_EXP_FAM_PER_CASH_GDP': nan,
#  'HT_SH_XPD_CHEX_GD_ZS': 'Current health expenditure',
#  'HT_SH_XPD_GHED_GD_ZS': 'Domestic general government health expenditure',
#  'EC_ENV_GOV_EXP_GDP': nan,
#  'EC_HOU_GOV_EXP_GDP': nan,
#  'EC_HT_GOV_EXP_GDP': nan,
#  'EC_PUB_GOV_EXP_GDP': nan,
#  'EC_EA_GOV_EXP_GDP': nan,
#  'EC_EDU_GOV_EXP_GDP': nan,
#  'EC_SAF_GOV_EXP_GDP': nan,
#  'EC_REC_GOV_EXP_GDP': nan,
#  'EC_EXP_FAM_CHLD_EUR': nan,
#  'EC_EXP_FAM_CHLD_PPS': nan,
#  'EC_EXP_FAM_KIND_CARE_GDP': nan,
#  'EC_EXP_FAM_KIND_ACCO_GDP': nan,
#  'EC_EXP_FAM_KIND_HOME_GDP': nan,
#  'EC_EXP_FAM_KIND_OTHER_GDP': nan,
#  'EC_EXP_FAM_LUMP_CASH_BIRTH_GDP': nan,
#  'EC_EXP_FAM_LUMP_CASH_PAREN_GDP': nan,
#  'EC_EXP_FAM_LUMP_CASH_OTHER_GDP': nan,
#  'EC_EXP_FAM_PER_CASH_ALLOW_GDP': nan,
#  'EC_EXP_FAM_PER_CASH_BIRTH_GDP': nan,
#  'EC_EXP_FAM_PER_CASH_PAREN_GDP': nan,
#  'EC_EXP_FAM_PER_CASH_OTHER_GDP': nan,
#  'EC_TOT_GOV_EXP_GDP': nan,
#  'EC_FAM_PUB_EXP_GDP': nan,
#  'EC_FAM_PUB_EXP_TOT': nan,
#  'EDU_STAFF_COMP': nan,
#  'EDU_CAP_EXPEND': nan,
#  'EDU_CUR_EXPEND': nan,
#  'EC_DEF_GOV_EXP_GDP': nan,
#  'CR_IQ_SCI_OVRL': 'Statistical capacity score',
#  'CR_SG_REG_CENSUSN': 'Census',
#  'CR_SG_STT_NSDSFND': 'National statistical plans that are fully funded (SDG 17.18.3)',
#  'CR_SG_STT_NSDSIMPL': 'National statistical plans that are under implementation (SDG 17.18.3)',
#  'CR_SG_STT_NSDSFDGVT': 'National statistical plans with funding from government (SDG 17.18.3)',
#  'CR_SG_STT_NSDSFDDNR': 'National statistical plans with funding from donors (SDG 17.18.3)',
#  'CR_SG_STT_NSDSFDOTHR': 'National statistical plans with funding from others (SDG 17.18.3)',
#  'CR_SG_STT_FPOS': 'Compliance of national statistical legislation (SDG 17.18.2)',
#  'JJ_CHLD_COMPLAINT_HHRR': 'Number of children who lodged a complaint a human rights complaint during the year',
#  'JJ_CHLD_DISAB_COMPLAINT_HHRR': 'Number of children with disabilities who lodged a complaint a human rights complaint during the year',
#  'CR_SG_STT_CAPTY': 'Value of resources to strengthen statistical capacity (SDG 17.19.1)',
#  'HT_SH_ACS_UNHC': nan,
#  'HT_UHC_IDX': 'UHC Service Coverage Index (SDG 3.8.1)',
#  'HT_UHC_MAT': nan,
#  'HT_UHC_NCD': nan,
#  'HT_UHC_CAP': nan,
#  'HT_UHC_INFECT': nan,
#  'HT_SH_XPD_CHEX_PC_CD': nan,
#  'HT_SH_XPD_CHEX_PP_CD': nan,
#  'HT_SH_XPD_OOPC_CH_ZS': 'Out-of-pocket expenditure',
#  'HT_SH_XPD_OOPC_PP_CD': nan,
#  'HT_SH_XPD_OOPC_PC_CD': nan,
#  'HT_SH_XPD_PVTD_PC_CD': nan,
#  'HT_SH_XPD_PVTD_CH_ZS': nan,
#  'HT_SH_XPD_PVTD_PP_CD': nan,
#  'HT_SH_XPD_GHED_CH_ZS': 'Domestic general government health expenditure (% of current health expenditure)',
#  'HT_SH_XPD_GHED_GE_ZS': 'Domestic general government health expenditure (% of general government expenditure)',
#  'HT_SH_XPD_GHED_PP_CD': 'Domestic general government health expenditure per capita',
#  'HT_SH_XPD_GHED_PC_CD': nan,
#  'HT_WHO_GGHED_US': nan,
#  'HT_WHO_GGHED_GDP': nan,
#  'HT_INS_COV': 'Population covered by health insurance ',
#  'HT_ADOL_UNMETMED_NOUNMET': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_TOOEXP': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_TOOFAR': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_WAITING': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_TOOEFW': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_NOTIME': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_NOKNOW': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_FEAR': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_HOPING': 'Self-reported unmet needs for medical examination',
#  'HT_ADOL_UNMETMED_OTH': 'Self-reported unmet needs for medical examination',
#  'HT_SH_SUD_TREAT': nan,
#  'HT_SH_HAP_HBSAG': nan,
#  'HT_SH_TBS_INCD': nan,
#  'CME_SBR': 'Stillbirth rate',
#  'CME_MRM0': 'Neonatal mortality rate (SDG 3.2.2)',
#  'CME_PND': nan,
#  'CME_MRY0': 'Infant mortality rate',
#  'CME_MRY0T4': 'Under-five mortality rate (SDG 3.2.1)',
#  'CME_TMY0T4': 'Number of under-five deaths',
#  'HT_U5DEATH_AIDS': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_DIAR': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_PERT': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_TETA': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_MEAS': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_MENI': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_MALA': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_PNEU': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_PRET': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_INTR': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_SEPS': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_OTHE': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_CONG': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_NCDS': 'Under-five deaths detailed by cause',
#  'HT_U5DEATH_INJU': 'Under-five deaths detailed by cause',
#  'MNCH_MMR': nan,
#  'MNCH_BIRTH18': nan,
#  'MNCH_ANC4': nan,
#  'MNCH_INSTDEL': nan,
#  'MNCH_CSEC': 'C-section rate',
#  'MNCH_SAB': 'Births attended by skilled health personnel (SDG 3.1.2)',
#  'MNCH_PNCMOM': nan,
#  'NT_BW_LBW': 'Low birth weight among newborns',
#  'MNCH_PNEUCARE': nan,
#  'MNCH_MATERNAL_DEATHS': nan,
#  'MNCH_SH_MMR_RISK': nan,
#  'MNCH_SH_MMR_RISK_ZS': nan,
#  'IM_MCV1': nan,
#  'IM_MCV2': 'MCV2 coverage (SDG 3.b.1)',
#  'HT_DIST80DTP3_P': nan,
#  'IM_DTP1': nan,
#  'IM_DTP3': 'DTP3 coverage (SDG 3.b.1)',
#  'IM_PCV3': 'PCV3 coverage (SDG 3.b.1)',
#  'IM_HPV': 'HPV coverage (SDG 3.b.1)',
#  'HT_SH_ACS_PCV3': nan,
#  'HT_DIST79DTP3_P': nan,
#  'HT_DIST79MCV2_P': nan,
#  'HT_SH_ACS_DTP3': nan,
#  'HT_SH_ACS_HPV': nan,
#  'HT_SH_ACS_MCV2': nan,
#  'HT_COVERAGE_DTP3': nan,
#  'NT_BF_EIBF': 'Early initiation of breastfeeding',
#  'NT_BF_EXBF': 'Exclusive breastfeeding',
#  'NT_CF_MAD': 'Minimum acceptable diet',
#  'HT_SH_STA_ANEM': 'Anaemia among women (SDG 2.2.3 )',
#  'HT_SH_STA_ANEM_NPRG': nan,
#  'HT_SH_STA_ANEM_PREG': nan,
#  'NT_ANT_WHZ_NE2': 'Prevalence of wasting',
#  'NT_ANT_WHZ_PO2': 'Prevalence of overweight (SDG 2.2.2)',
#  'NT_ANT_HAZ_NE2': 'Prevalence of stunting (SDG 2.2.1 )',
#  'NT_CF_ISSSF_FL': 'Introduction to solid, semi-solid foods',
#  'NT_CF_MDD': nan,
#  'NT_CF_MMF': nan,
#  'NT_CHLD_OBESITY': 'Prevalence of obesity',
#  'HT_ANEM_U5': 'Anaemia among children under 5 years',
#  'HT_SN_STA_OVWGTN': nan,
#  'NT_BW_UNW': nan,
#  'HT_NCD_BMI_18A': nan,
#  'FT_SP_DYN_ADKL': 'Adolescent birth rate (SDG 3.7.2)',
#  'HT_ADOL_MT': 'Adolescent mortality rate',
#  'MT_SDG_SUICIDE': 'Suicide rate (SDG 3.4.2)',
#  'HT_ADOL_VGRS_EXCS': 'Adolescents who report regularly engaging in vigorous physical activity outside of school ',
#  'HT_ADOL_NO_EXCS': 'Adolescents who report doing no physical activity outside of school',
#  'HT_ADOL_HIGH_SATS': nan,
#  'HT_ADOL_LOW_SATS': nan,
#  'HT_SH_PRV_SMOK': nan,
#  'HT_SH_SUD_ALCOL': nan,
#  'HT_CHLD_DAILY_EXER': 'WHO-recommended daily exercise',
#  'HT_SH_FPL_MTMM': nan,
#  'HT_CDRT_SELF_HARM': nan,
#  'HT_ADOL_MEAL': nan,
#  'HT_CHLD_BODY_RGHT': nan,
#  'HT_CHLD_BODY_NO_RGHT': nan,
#  'HT_CHLD_REG_SMOK': nan,
#  'HT_CHLD_DRNK': nan,
#  'HT_CHLD_HEALTH_POOR': nan,
#  'HT_CHLD_HEALTH_PROB': nan,
#  'HT_CHLD_SUP_FAM': nan,
#  'HT_CHLD_SELF_EFFICACY': nan,
#  'HT_CHLD_GROWTH_MIND': nan,
#  'HT_CHLD_HEALTH_COMP': nan,
#  'HT_CHLD_LIFE_PURP': nan,
#  'HT_CHLD_DIFF_PAR': nan,
#  'HT_CHLD_PAR_CONF': nan,
#  'HT_CHLD_FRIENDS': nan,
#  'HT_CHLD_SUP_FRIENDS': nan,
#  'HVA_PREV_KNOW': nan,
#  'HVA_EPI_LHIV_15-24': nan,
#  'HT_SH_HIV_0014': nan,
#  'HVA_EPI_LHIV_0-19': 'Children living with HIV',
#  'HVA_PED_ART_CVG': 'Children receiving ART',
#  'HVA_PMTCT_ARV_CVG': nan,
#  'HT_SH_HIV_INCD': nan,
#  'HVA_EPI_INF_ANN_0-19': nan,
#  'HVA_EPI_INF_ANN_15-24': nan,
#  'HVA_EPI_INF_RT_0-14': 'New HIV infections (SDG 3.3.1) ',
#  'HVA_EPI_INF_RT_10-19': nan,
#  'HVA_EPI_DTH_ANN_0-19': 'Annual AIDS-related deaths',
#  'HVA_PMTCT_MTCT': 'Mother-to-child HIV transmission rate',
#  'HVA_PMTCT_STAT_CVG': 'Pregnant women and HIV testing',
#  'HVA_PED_ART_NUM': nan,
#  'HVA_PMTCT_STAT_NUM': nan,
#  'HVA_PREV_STIGMA': nan,
#  'EDU_FIN_EXP_CONST_PPP': nan,
#  'EDU_FIN_EXP_PT_TOT': nan,
#  'EDU_FIN_INIT_GOV_L02_GDP': nan,
#  'EDU_FIN_EXP_L02': 'Expenditure on pre-primary education',
#  'EDU_FIN_EXP_L1': 'Expenditure on primary education',
#  'EDU_FIN_EXP_L2': nan,
#  'EDU_FIN_EXP_L3': nan,
#  'EDU_FIN_EXP_L4': nan,
#  'EDU_FIN_EXP_L5T8': nan,
#  'EDUNF_COMP_YR_L02T3': nan,
#  'EDU_SDG_COMP_EDU_L02': 'Years of compulsory pre-primary education',
#  'EDU_SDG_COMP_EDU': nan,
#  'EDU_SDG_FREE_EDU_L02': 'Years of free pre-primary education',
#  'EDUNF_ADMIN_L1_G2OR3_REA': nan,
#  'EDUNF_ADMIN_L1_G2OR3_MAT': nan,
#  'EDUNF_ADMIN_L1_GLAST_REA': 'Learning assessments in reading (end of primary education)',
#  'EDUNF_ADMIN_L1_GLAST_MAT': 'Learning assessments in math (end of primary education)',
#  'EDUNF_ADMIN_L2_REA': 'Learning assessments in reading (end of lower secondary education)',
#  'EDUNF_ADMIN_L2_MAT': 'Learning assessments in math (end of lower secondary education)',
#  'EDU_SDG_FREE_EDU': nan,
#  'EDU_DURATION_ECE': nan,
#  'EDU_DURATION_L02': nan,
#  'EDU_DURATION_L1': nan,
#  'EDU_DURATION_L2': nan,
#  'EDU_DURATION_L3': nan,
#  'EDU_ENTER_AGE_ECED': nan,
#  'EDU_ENTER_AGE_L02': nan,
#  'EDU_ENTER_AGE_L1': nan,
#  'EDU_ENTER_AGE_L2': nan,
#  'EDU_ENTER_AGE_L3': nan,
#  'EDU_ENTER_AGE_L4': nan,
#  'EDU_ENTER_AGE_COMP': nan,
#  'EDU_DURATION_ECED': nan,
#  'EDU_DURATION_L4': nan,
#  'EDUNF_STU_L02_PUB': nan,
#  'EDUNF_STU_L02_PRV': nan,
#  'EDUNF_PRP_L02': nan,
#  'EDUNF_STU_L1_PUB': nan,
#  'EDUNF_STU_L1_PRV': nan,
#  'EDUNF_PRP_L1': nan,
#  'EDUNF_STU_L2_PUB': nan,
#  'EDUNF_STU_L2_PRV': nan,
#  'EDUNF_PRP_L2': nan,
#  'EDUNF_STU_L3_PUB': nan,
#  'EDUNF_STU_L3_PRV': nan,
#  'EDUNF_PRP_L3': nan,
#  'EDUNF_STU_L4_PUB': nan,
#  'EDUNF_STU_L4_PRV': nan,
#  'EDUNF_PRP_L4': nan,
#  'EDUNF_STU_L5T8_PUB': nan,
#  'EDUNF_STU_L5T8_PRV': nan,
#  'EDUNF_PRP_L5T8': nan,
#  'EDUNF_TEACH_L1': nan,
#  'EDUNF_TEACH_L2': nan,
#  'EDUNF_TEACH_L3': nan,
#  'EDUNF_PTR_L1': nan,
#  'EDUNF_PTR_L2': nan,
#  'EDUNF_PTR_L2AND3': nan,
#  'EDUNF_PTR_L3': nan,
#  'EDUNF_PRP_L2AND3': nan,
#  'EDUNF_STU_L2AND3_PRV': nan,
#  'EDUNF_COMP_YR': nan,
#  'EDUNF_PTR_L02': nan,
#  'ECD_CHLD_36-59M_EDU-PGM': nan,
#  'EDU_ECEC_PART': nan,
#  'EDUNF_STU_L01_TOT': nan,
#  'EDUNF_STU_L01_PUB': nan,
#  'EDUNF_STU_L01_PRV': nan,
#  'EDUNF_NERA_L1_UNDER1': 'Participation in organized learning - administrative data (SDG 4.2.2)',
#  'EDUNF_NARA_L1_UNDER1': nan,
#  'EDUNF_NERA_L1': nan,
#  'EDUNF_NERA_L2': nan,
#  'ED_ANAR_L1': nan,
#  'ED_ANAR_L2': nan,
#  'ED_ANAR_L3': nan,
#  'EDU_CHLD_DISAB': nan,
#  'EDU_CHLD_DISAB_GENERAL': nan,
#  'EDU_CHLD_DISAB_SPECIAL': nan,
#  'EDU_CHLD_DISAB_HOME': nan,
#  'EDU_CHLD_DISAB_L02': nan,
#  'EDU_CHLD_DISAB_L1': nan,
#  'EDU_CHLD_DISAB_L2': nan,
#  'EDU_CHLD_DISAB_L3': nan,
#  'EDUNF_TRANRA_L2': nan,
#  'EDUNF_OFST_L1': nan,
#  'EDUNF_OFST_L2': nan,
#  'EDUNF_OFST_L3': nan,
#  'EDUNF_ROFST_L1': 'Out-of-school rate - primary school age ',
#  'EDUNF_ROFST_L2': 'Out-of-school rate - lower secondary school age',
#  'EDUNF_ROFST_L3': 'Out-of-school rate - upper secondary school age',
#  'EDUNF_OFST_L1_UNDER1': nan,
#  'EDUNF_ROFST_L1_UNDER1': 'Out-of-school rate - one year younger than entry age to primary education ',
#  'EDUNF_DR_L1': nan,
#  'EDUNF_DR_L2': nan,
#  'EDUNF_CR_L1': 'Completion rate - primary education (SDG 4.1.2)',
#  'EDUNF_CR_L2': 'Completion rate - lower secondary education (SDG 4.1.2)',
#  'EDUNF_CR_L3': 'Completion rate - upper secondary education (SDG 4.1.2)',
#  'EDU_SE_AGP_CPRA_L1': nan,
#  'EDU_SE_AGP_CPRA_L2': nan,
#  'EDU_SE_AGP_CPRA_L3': 'Gender parity index for completion rate (SDG 4.5.1)',
#  'EDUNF_EA_L2T8': nan,
#  'EDAT_LFSE_14': 'Early leavers from education and training',
#  'EDUNF_SR_L1': nan,
#  'EDUNF_SR_L2': nan,
#  'EDU_SDG_PRYA': 'Youth and adults in education and training (SDG 4.3.1)',
#  'EDUNF_ESL_L1': nan,
#  'EDU_SDG_SCH_L1': 'Primary schools adapted infrastructure and materials (SDG 4.a.1)',
#  'EDU_SDG_SCH_L2': 'Lower secondary schools with adapted infrastructure and materials (SDG 4.a.1)',
#  'EDU_SDG_SCH_L3': 'Upper secondary schools with adapted infrastructure and materials (SDG 4.a.1)',
#  'WS_SCH_H-B': nan,
#  'WS_SCH_S-B': nan,
#  'WS_SCH_W-B': nan,
#  'EDU_SE_ACS_INTNT_L1': nan,
#  'EDU_SE_ACS_INTNT_L2': nan,
#  'EDU_SE_ACS_INTNT_L3': nan,
#  'EDU_SE_ACS_CMPTR_L1': nan,
#  'EDU_SE_ACS_CMPTR_L2': nan,
#  'EDU_SE_ACS_CMPTR_L3': nan,
#  'EDU_SE_ACS_ELECT_L1': nan,
#  'EDU_SE_ACS_ELECT_L2': nan,
#  'EDU_SE_ACS_ELECT_L3': nan,
#  'EDU_SE_TOT_GPI_L2_REA': 'Gender parity index for achieving proficiency in reading (SDG 4.5.1)',
#  'EDU_SE_TOT_GPI_L2_MAT': 'Gender parity index for achieving proficiency in math (SDG 4.5.1)',
#  'EDU_SDG_GER_L01': nan,
#  'EDUNF_STU_L02_TOT': nan,
#  'EDUNF_GER_L02': nan,
#  'EDUNF_NER_L02': nan,
#  'EDUNF_FEP_L02': nan,
#  'EDUNF_NIR_L1_ENTRYAGE': nan,
#  'EDUNF_STU_L1_TOT': nan,
#  'EDUNF_FEP_L1': nan,
#  'EDUNF_STU_L2_TOT': nan,
#  'EDUNF_FEP_L2': nan,
#  'EDUNF_STU_L3_TOT': nan,
#  'EDUNF_FEP_L3': nan,
#  'EDUNF_FEP_L3_GEN': nan,
#  'EDUNF_FEP_L3_VOC': nan,
#  'EDUNF_STU_L3_GEN': nan,
#  'EDUNF_STU_L3_VOC': nan,
#  'EDUNF_STU_L3_GEN_PUB': nan,
#  'EDUNF_STU_L3_GEN_PRV': nan,
#  'EDUNF_STU_L3_VOC_PUB': nan,
#  'EDUNF_STU_L3_VOC_PRV': nan,
#  'EDUNF_GER_L1': nan,
#  'EDUNF_GER_L2': nan,
#  'EDUNF_GER_L1AND2': nan,
#  'EDUNF_GER_L2_GEN': nan,
#  'EDUNF_GER_L2_VOC': nan,
#  'EDUNF_GER_L3': nan,
#  'EDUNF_GER_L3_GEN': nan,
#  'EDUNF_GER_L3_VOC': nan,
#  'EDUNF_STU_L4_TOT': nan,
#  'EDUNF_FEP_L4': nan,
#  'EDUNF_STU_L5T8_TOT': nan,
#  'EDUNF_FEP_L5T8': nan,
#  'EDUNF_GER_GPI_L02': nan,
#  'EDUNF_GER_GPI_L1': nan,
#  'EDUNF_GER_GPI_L2': nan,
#  'EDUNF_GER_GPI_L3': nan,
#  'EDUNF_GER_GPI_L2AND3': nan,
#  'EDU_CHLD_DISAB_GENERAL_BOARDING': nan,
#  'EDU_CHLD_DISAB_SPECIAL_BOARDING': nan,
#  'EDUNF_GER_GPI_L01': nan,
#  'EDUNF_OFST_L1T3': nan,
#  'EDUNF_ROFST_L1T3': nan,
#  'EDUNF_GECER_L01': nan,
#  'EDUNF_GECER_L02': nan,
#  'EDU_SE_TOT_GPI_L1_REA': nan,
#  'EDU_SE_TOT_GPI_L1_MAT': nan,
#  'EDU_SE_TOT_GPI_FS_LIT': nan,
#  'EDU_SE_TOT_GPI_FS_NUM': nan,
#  'EDU_SE_GPI_PART': nan,
#  'EDU_SE_GPI_PTNPRE': nan,
#  'EDU_SE_GPI_TCAQ_L02': nan,
#  'EDU_SE_GPI_TCAQ_L1': nan,
#  'EDU_SE_GPI_TCAQ_L2': nan,
#  'EDU_SE_GPI_TCAQ_L3': nan,
#  'EDU_SE_NAP_ACHI_L1_REA': nan,
#  'EDU_SE_NAP_ACHI_L2_REA': nan,
#  'EDU_SE_NAP_ACHI_L1_MAT': nan,
#  'EDU_SE_NAP_ACHI_L2_MAT': nan,
#  'EDU_SE_IMP_FPOF_LIT': nan,
#  'EDU_SE_IMP_FPOF_NUM': nan,
#  'EDU_SE_LGP_ACHI_L1_REA': nan,
#  'EDU_SE_LGP_ACHI_L2_REA': nan,
#  'EDU_SE_LGP_ACHI_L1_MAT': nan,
#  'EDU_SE_LGP_ACHI_L2_MAT': nan,
#  'EDU_SE_ALP_CPLR_L1': nan,
#  'EDU_SE_ALP_CPLR_L2': nan,
#  'EDU_SE_ALP_CPLR_L3': nan,
#  'EDU_SE_TOT_SESPI_L1_REA': nan,
#  'EDU_SE_TOT_SESPI_L2_REA': nan,
#  'EDU_SE_TOT_SESPI_L1_MAT': nan,
#  'EDU_SE_TOT_SESPI_L2_MAT': nan,
#  'EDU_SE_TOT_SESPI_FS_LIT': nan,
#  'EDU_SE_TOT_SESPI_FS_NUM': nan,
#  'EDU_SE_TOT_RUPI_L1_REA': nan,
#  'EDU_SE_TOT_RUPI_L2_REA': nan,
#  'EDU_SE_TOT_RUPI_L1_MAT': nan,
#  'EDU_SE_TOT_RUPI_L2_MAT': nan,
#  'EDU_SE_AWP_CPRA_L1': nan,
#  'EDU_SE_AWP_CPRA_L2': nan,
#  'EDU_SE_AWP_CPRA_L3': nan,
#  'EDUNF_STEM_GRAD_RT': nan,
#  'EDUNF_GER_L5T8': nan,
#  'EDUNF_GER_GPI_L5T8': nan,
#  'EDU_CHLD_Y04_COMP_AGE': nan,
#  'EDU_CHLD_Y0T2_ECEC_PART': nan,
#  'EDU_SDG_QUTP_L02': nan,
#  'EDU_SDG_QUTP_L1': nan,
#  'EDU_SDG_QUTP_L2': nan,
#  'EDU_SDG_QUTP_L3': nan,
#  'EDU_PISA_MAT': nan,
#  'EDU_PISA_REA': nan,
#  'EDU_PISA_SCI': nan,
#  'EDU_PISA_LOW_ACHIEVE_MAT': '15-year-olds achieving low scores in mathematics',
#  'EDU_PISA_LOW_ACHIEVE_REA': '15-year-olds achieving low scores in reading',
#  'EDU_PISA_LOW_ACHIEVE_SCI': '15-year-olds achieving low scores in science',
#  'EDU_SDG_STU_L1_G2OR3_REA': nan,
#  'EDU_SDG_STU_L1_G2OR3_MAT': nan,
#  'EDU_SDG_STU_L2_GLAST_REA': 'Children at the end of lower secondary education reaching minimum proficiency in reading (SDG 4.1.1)',
#  'EDU_SDG_STU_L2_GLAST_MAT': 'Children at the end of lower secondary education reaching minimum proficiency in math (SDG 4.1.1)',
#  'EDU_SDG_YOUTH_NEET': ' Percentage of youth not in education, employment or training (SDG 8.6.1)',
#  'EDU_PISA_MAT2': nan,
#  'EDU_PISA_MAT3': nan,
#  'EDU_PISA_MAT4': nan,
#  'EDU_PISA_MAT5': nan,
#  'EDU_PISA_MAT6': nan,
#  'EDU_PISA_REA2': nan,
#  'EDU_PISA_REA3': nan,
#  'EDU_PISA_REA4': nan,
#  'EDU_PISA_REA5': nan,
#  'EDU_PISA_REA6': nan,
#  'EDU_PISA_SCI2': nan,
#  'EDU_PISA_SCI3': nan,
#  'EDU_PISA_SCI4': nan,
#  'EDU_PISA_SCI5': nan,
#  'EDU_PISA_SCI6': nan,
#  'EDUNF_LR_ADULT': nan,
#  'EDU_SDG_STU_L1_GLAST_REA': nan,
#  'EDU_SDG_STU_L1_GLAST_MAT': nan,
#  'EDU_TIMSS_MAT4': nan,
#  'EDU_TIMSS_SCI4': nan,
#  'EDU_TIMSS_MAT8': nan,
#  'EDU_TIMSS_SCI8': nan,
#  'EDU_PIRLS_REA': nan,
#  'EDUNF_LR_YOUTH': nan,
#  'EDUNF_RPTR_L1': nan,
#  'EDUNF_RPTR_L2': nan,
#  'EDUNF_REPP_L1': nan,
#  'EDUNF_REPP_L2': nan,
#  'EDUNF_FRP_L1': nan,
#  'EDU_SDG_TRTP_L02': nan,
#  'EDU_SDG_TRTP_L1': nan,
#  'EDU_SDG_TRTP_L2': nan,
#  'EDU_SDG_TRTP_L3': nan,
#  'EDU_SDG_PTTR_L02': nan,
#  'EDU_SDG_PTTR_L1': nan,
#  'EDU_SDG_PTTR_L2': nan,
#  'EDU_SDG_PTTR_L3': nan,
#  'EDU_SDG_PQTR_L02': nan,
#  'EDU_SDG_PQTR_L1': nan,
#  'EDU_SDG_PQTR_L2': nan,
#  'EDU_SDG_PQTR_L3': nan,
#  'ECD_CHLD_U5_BKS-HM': nan,
#  'ECD_CHLD_U5_PLYTH-HM': nan,
#  'EDUNF_FRP_L2AND3': nan,
#  'EDU_CHLD_TOP_REA': nan,
#  'EDU_CHLD_TOP_MAT_SCI': nan,
#  'EDU_CHLD_TOP_REA_MAT_SCI': nan,
#  'EDU_CHLD_EXP_COMP_L5': nan,
#  'EDU_CHLD_ELA_PAR': nan,
#  'EDU_CHLD_HIGH_SS': nan,
#  'EDU_CHLD_POOR_DISC': nan,
#  'EDU_CHLD_BELONG_SCH': nan,
#  'PP_ADOL_INET': 'Adolescents who use the internet and social networks before or after school',
#  'PP_ADOL_TVGM': 'Adolescents who watch TV or play video games before or after school',
#  'PP_ADOL_ITXT': nan,
#  'PP_ADOL_WORK_PAID': nan,
#  'PP_ADOL_WORK_HOME': nan,
#  'PP_CHLD_PROB_SM': nan,
#  'PP_CHLD_VICTIM_CB': nan,
#  'PP_CHLD_INT_RESOURCE': nan,
#  'PT_F_15-49_W-BTNG': nan,
#  'PT_M_15-49_W-BTNG': nan,
#  'PT_F_GE15_PS-SX-EM_V_PTNR_12MNTH': 'Violence by an intimate partner (SDG 5.2.1)',
#  'PT_F_GE15_SX_V_PTNR_12MNTH': nan,
#  'PT_ST_13-15_BUL_30-DYS': 'Bullying',
#  'PT_ADLT_PS_NEC': 'Attitudes to physical punishment',
#  'PT_CHLD_1-14_PS-PSY-V_CGVR': 'Physical punishment and/or psychological aggression by caregivers (SDG 16.2.1)',
#  'PT_F_18-29_SX-V_AGE-18': 'Sexual violence by age 18 (SDG 16.2.3)',
#  'PT_M_18-29_SX-V_AGE-18': nan,
#  'PT_CHLD_VIOLENCE_WELFARE': 'Child victims of violence',
#  'PT_CHLD_VIOLENCE_HEALTHCARE': nan,
#  'PT_CHLD_VIOLENCE_EDUCATION': nan,
#  'PT_VC_SNS_WALN': nan,
#  'PT_CHLD_DISAB_VIOLENCE_WELFARE': nan,
#  'PT_CHLD_DISAB_VIOLENCE_HEALTHCARE': nan,
#  'PT_CHLD_DISAB_VIOLENCE_EDUCATION': nan,
#  'PT_VC_VOV_PHYL': nan,
#  'PT_VC_VOV_SEXL': nan,
#  'PT_VC_VOV_ROBB': nan,
#  'PT_VC_PRR_PHYV': nan,
#  'PT_VC_PRR_SEXV': nan,
#  'PT_VC_PRR_ROBB': nan,
#  'PT_CHLD_15_BUL_SCH': nan,
#  'PT_CHLD_VIOLENCE_LOCAL': nan,
#  'PT_CHLD_INRESIDENTIAL': nan,
#  'PT_CHLD_INFORMALCARE_RATE': 'Children in formal alternative care',
#  'PT_CHLD_DISAB_INRESIDENTIAL': nan,
#  'PT_CHLD_INRESIDENTIAL_RATE_B': 'Children in formal residential care',
#  'PT_CHLD_CARED_BY_FOSTER': nan,
#  'PT_CHLD_DISAB_FOSTER': nan,
#  'PT_CHLD_INKINSHIP': nan,
#  'PT_CHLD_DISAB_INKINSHIP': nan,
#  'PT_CHLD_INOTHER_FAMILY': nan,
#  'PT_CHLD_DISAB_INOTHER_FAMILY': nan,
#  'PT_CHLD_DISAB_INALL_FAMILY': nan,
#  'PT_CHLD_INCARE_FOSTER_RATE': 'Children in formal family-based care',
#  'PT_CHLD_NO_PARENTAL_CARE_INRESIDENTIAL': nan,
#  'PT_CHLD_ENTER_ALLFAMILY': nan,
#  'PT_CHLD_ENTEREDKINSHIP': nan,
#  'PT_CHLD_ENTEREDFOSTER': nan,
#  'PT_CHLD_ENTEREDOTHER_FAMILY': nan,
#  'PT_CHLD_ENTER_RESIDENTIAL_RATE': nan,
#  'PT_CHLD_ENTEREDFAMILY_RATE': nan,
#  'PT_CHLD_DISAB_ENTER_RESIDENTIAL': nan,
#  'PT_CHLD_DISAB_ENTEREDFOSTER': nan,
#  'PT_CHLD_DISAB_ENTEREDKINSHIP': nan,
#  'PT_CHLD_DISAB_ENTEREDOTHER_FAMILY': nan,
#  'PT_CHLD_DISAB_ENTER_ALLFAMILY': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_REUNION': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_FAMILY': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_ADOPT': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_INDEP': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_DEATH': nan,
#  'PT_CHLD_LEFT_RESIDENTIAL_OTHER': nan,
#  'PT_CHLD_LEFTFOSTER': nan,
#  'PT_CHLD_LEFTFOSTER_RETURNED': nan,
#  'PT_CHLD_LEFTFOSTER_EDUINSTITUTION': nan,
#  'PT_CHLD_LEFT_ALLFAMILY': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_REUNION': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_RESIDENTIAL': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_ADOPT': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_INDEP': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_DEATH': nan,
#  'PT_CHLD_LEFT_ALLFAMILY_OTHER': nan,
#  'PT_CHLD_LEFTFOSTER_FAMILY': nan,
#  'PT_CHLD_LEFTFOSTER_ADOPT': nan,
#  'PT_CHLD_LEFTFOSTER_INDEP': nan,
#  'PT_CHLD_LEFTFOSTER_DEATH': nan,
#  'PT_CHLD_LEFTFOSTER_OTHER_REASON': nan,
#  'PT_CHLD_LEFT_KINSHIP': nan,
#  'PT_CHLD_LEFT_KINSHIP_REUNION': nan,
#  'PT_CHLD_LEFT_KINSHIP_FAMILY': nan,
#  'PT_CHLD_LEFT_KINSHIP_RESIDENTIAL': nan,
#  'PT_CHLD_LEFT_KINSHIP_ADOPT': nan,
#  'PT_CHLD_LEFT_KINSHIP_INDEP': nan,
#  'PT_CHLD_LEFT_KINSHIP_DEATH': nan,
#  'PT_CHLD_LEFT_KINSHIP_OTHER': nan,
#  'PT_CHLD_LEFT_FAMILY': nan,
#  'PT_CHLD_LEFT_FAMILY_REUNION': nan,
#  'PT_CHLD_LEFT_FAMILY_FOSTER': nan,
#  'PT_CHLD_LEFT_FAMILY_RESIDENTIAL': nan,
#  'PT_CHLD_LEFT_FAMILY_ADOPT': nan,
#  'PT_CHLD_LEFT_FAMILY_INDEP': nan,
#  'PT_CHLD_LEFT_FAMILY_DEATH': nan,
#  'PT_CHLD_LEFT_FAMILY_OTHER': nan,
#  'PT_CHLD_DISAB_LEFT_RESIDENTIAL': nan,
#  'PT_CHLD_DISAB_LEFTFOSTER': nan,
#  'PT_CHLD_DISAB_LEFT_KINSHIP': nan,
#  'PT_CHLD_DISAB_LEFT_FAMILY': nan,
#  'PT_CHLD_DISAB_LEFT_ALLFAMILY': nan,
#  'PT_CHLD_INRESIDENTIAL_PROP': nan,
#  'PT_CHLD_ALLFAMILY_PROP': nan,
#  'PT_CHLD_INFOSTER_PROP': nan,
#  'PT_CHLD_INKINSHIP_PROP': nan,
#  'PT_CHLD_INOTHER_FAMILY_PROP': nan,
#  'PT_CHLD_ADOPTION': nan,
#  'PT_CHLD_ADOPTION_INTERCOUNTRY': nan,
#  'PT_CHLD_ADOPT_DOMESTIC': nan,
#  'PT_CHLD_ADOPTION_RATE': 'Rate of formal adoption of children',
#  'PT_CHLD_ADOPT_DOMESTIC_RATE': nan,
#  'PT_CHLD_ADOPTION_INTERCOUNTRY_RATE': nan,
#  'PT_CHLD_ADOPTION_DISAB': nan,
#  'PT_CHLD_ADOPTION_INTER_COUNTRY_DISAB': nan,
#  'PT_CHLD_DISAB_ADOPT_DOMESTIC': nan,
#  'PT_CHLD_DISAB_INRESIDENTIAL_PROP': 'Children with disabilities in formal residential care',
#  'PT_CHLD_DISAB_INFOSTER_PROP': 'Children with disabilities in formal foster care of the total number of children in formal family-based care',
#  'PT_CHLD_DISAB_INFAMILY_PROP': 'Children with disabilities in formal family-based care',
#  'PT_CHLD_DISAB_LEFT_RESIDENTIAL_PROP': nan,
#  'PT_CHLD_DISAB_ENTEREDFAMILY_PROP': nan,
#  'PT_CHLD_DISAB_ENTER_RESIDENTIAL_PROP': nan,
#  'PT_CHLD_DISAB_INKINSHIP_PROP': nan,
#  'PT_CHLD_DISAB_INOTHER_FAMILY_PROP': nan,
#  'PT_CHLD_DISAB_ADOPT_PROP': nan,
#  'PT_CHLD_DISAB_ADOPT_DOMESTIC_PROP': nan,
#  'PT_CHLD_DISAB_ADOPT_INTERCOUNTRY_PROP': nan,
#  'PT_YOUNG_INRESIDENTIAL': nan,
#  'PT_YOUNG_DISAB_INRESIDENTIAL': nan,
#  'PT_YOUNG_DISAB_INALL_FAMILY': nan,
#  'PT_YOUNG_LEFT_ALLFAMILY': nan,
#  'PT_YOUNG_DISAB_LEFT_ALLFAMILY': nan,
#  'PT_YOUNG_LEFT_RESIDENTIAL': nan,
#  'PT_YOUNG_DISAB_LEFT_RESIDENTIAL': nan,
#  'PT_YOUNG_INALL_FAMILY': nan,
#  'JJ_CHLD_DETENTION_RATE': 'Children in detention',
#  'JJ_CHLD_PRETRIAL': nan,
#  'JJ_CHLD_PRE_SENTENCE_DETENTION_RATE': 'Children in pre-sentence detention',
#  'JJ_CHLD_PRISION_ADJUDICATION': nan,
#  'JJ_CHLD_POST_SENTENCE_DETENTION_RATE': 'Children in post-sentence detention',
#  'JJ_CHLD_DETENTION': nan,
#  'JJ_CHLD_ENTER_PRE_SENTENCE_DETENTION_RATE': 'Children detained in pre-sentence detention during the year',
#  'JJ_VC_PRS_UNSNT': 'Unsentenced detainees (SDG 16.3.2)',
#  'JJ_CHLD_VICTIM_CRIME': nan,
#  'JJ_CHLD_VICTIM_CRIME_RATE': 'Child victims of crime',
#  'JJ_CHLD_WITNESS_CRIME': nan,
#  'JJ_CHLD_WITNESS_CRIME_RATE': 'Child witnesses of crime ',
#  'JJ_CHLD_CUSTODIAL_SENTENCE': nan,
#  'JJ_CHLD_ALTERNATIVE_SENTENCE': nan,
#  'JJ_CHLD_CUSTODIAL_SENTENCE_PROP': 'Children sentenced to custodial sentences',
#  'JJ_CHLD_ALTERNATIVE_SENTENCE_PROP': 'Children sentenced with alternative measures',
#  'JJ_CHLD_POST_SENTENCE_DETENTION': nan,
#  'JJ_CHLD_ENTER_DETENTION_RATE': nan,
#  'JJ_CHLD_ENTER_POST_SENTENCE_DETENTION_RATE': nan,
#  'JJ_PRISIONERS': nan,
#  'JJ_PRISIONERS_RT': nan,
#  'PT_F_15-19_MRD': 'Girls aged 15-19 years who are currently married or in union',
#  'PT_M_15-19_MRD': 'Boys aged 15-19 years who are currently married or in union',
#  'PT_F_20-24_MRD_U18': 'Women aged 20-24 years married or in union before age 18 (SDG 5.3.1)',
#  'PT_M_20-24_MRD_U18': 'Men aged 20-24 years married or in union before age 18',
#  'PT_F_20-24_MRD_U15': nan,
#  'PT_CHLD_5-17_LBR_ECON-HC': 'Child labour - economic activities and household chores (SDG 8.7.1)',
#  'PT_CHLD_5-17_LBR_ECON': 'Child labour - economic activities',
#  'PT_ADLS_10-14_LBR_HC': nan,
#  'PP_SG_REG_BRTH90N': 'Birth registration data (SDG 17.19.2)',
#  'PP_SG_REG_DETH75N': 'Death registration data (SDG 17.19.2)',
#  'PT_CHLD_Y0T4_REG': 'Birth registration with a civil authority (SDG 16.9.1)',
#  'PP_CHLD_VOL_WORK': nan,
#  'PP_CHLD_PLACE_PLAY': nan,
#  'PP_IT_MOB_OWN': nan,
#  'PP_SE_ADT_ACTS_PRGM': 'ICT skills: writing a computer program using a specialized programming language (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_ATCH': 'ICT skills: sending e-mails with attached files (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_SFWR': 'ICT skills: finding, downloading, installing and configuring software (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_CPT': 'ICT skills: using copy and paste tools to duplicate or move information within a document (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_CDV': 'ICT skills: connecting and installing new devices (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_SSHT': 'ICT skills: using basic arithmetic formula in a spreadsheet (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_PST': ' ICT skills: creating electronic presentations with presentation software (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_TRFF': 'ICT skills: transferring files between a computer and other devices (SDG 4.4.1)',
#  'PP_SE_ADT_ACTS_CMFL': 'ICT skills: copying or moving a file or folder (SDG 4.4.1)',
#  'PP_IT_USE_ii99': 'Internet use (SDG 17.8.1)',
#  'ICT_PERSONAL_DATA': 'Privacy and protection of personal data',
#  'ICT_SECURITY_CONCERN': 'Internet security concerns',
#  'PP_SE_GPI_ICTS_ATCH': nan,
#  'PP_SE_GPI_ICTS_CPT': nan,
#  'PP_SE_GPI_ICTS_CDV': nan,
#  'PP_SE_GPI_ICTS_SSHT': nan,
#  'PP_SE_GPI_ICTS_PRGM': nan,
#  'PP_SE_GPI_ICTS_PST': nan,
#  'PP_SE_GPI_ICTS_SFWR': nan,
#  'PP_SE_GPI_ICTS_TRFF': nan,
#  'PP_SE_GPI_ICTS_CMFL': nan,
#  'PV_SI_COV_BENFTS': 'Population covered by at least one social protection benefit (SDG 1.3.1)',
#  'PV_SI_COV_LMKT': nan,
#  'PV_SI_COV_SOCAST': nan,
#  'PV_SI_COV_SOCINS': nan,
#  'PV_SI_COV_VULN': 'Vulnerable population receiving social assistance cash benefit  (SDG 1.3.1)',
#  'PV_SI_COV_DISAB': 'Population with severe disabilities receiving disability cash benefit (SDG 1.3.1)',
#  'PV_SI_COV_POOR': 'Poor population receiving social assistance cash benefit (SDG 1.3.1)',
#  'PV_SI_COV_MATNL': 'Mothers with newborns receiving maternity cash benefit (SDG 1.3.1)',
#  'PV_SI_COV_CHLD': 'Children/households receiving child/family cash benefit (SDG 1.3.1)',
#  'GN_MTNTY_LV_BNFTS': nan,
#  'GN_PTNTY_LV_BNFTS': nan,
#  'PV_SI_COV_UEMP': 'Unemployed persons receiving unemployment cash benefit (SDG 1.3.1)',
#  'PV_SI_COV_WKINJRY': nan,
#  'PV_SI_COV_PENSN': nan,
#  'SP_EXP_CHLD_DISAB_CASH': nan,
#  'PV_SI_POV_DAY1': nan,
#  'PV_SDG_SI_POV_NAHC': 'Population living below the national poverty line (SDG 1.2.1)',
#  'SI_POV_UMIC': 'Poverty headcount ratio at $6.85 a day',
#  'PV_AROPE': 'People at risk of poverty or social exclusion',
#  'PV_AROPRT': 'At-risk-of-poverty rate',
#  'PV_SD_MDP_MUHC': nan,
#  'PV_SEV_MAT_SOC_DPRT': 'Severe material and social deprivation rate',
#  'PV_LOW_WORK': 'Low work intensity',
#  'PV_INABLE_PROTEIN': 'Inability to afford a meal with protein',
#  'PV_SI_POV_EMP1': nan,
#  'PV_SI_POV_UMIC': nan,
#  'PV_WB_SI_POV_NAHC': nan,
#  'PV_SD_MDP_CSMP': nan,
#  'PV_SD_MDP_MUHHC': nan,
#  'PV_SI_POV_MDIM': nan,
#  'PV_SI_POV_MDIM_17': nan,
#  'WS_PPL_S-B': nan,
#  'PV_SEV_MAT_DPRT': nan,
#  'PV_CHLD_FOOD_DPRT': nan,
#  'PV_CHLD_HOUS_DPRT': nan,
#  'PV_CHLD_MAT_DPRT': nan,
#  'PV_CHLD_NO_INTERNET': nan,
#  'PV_CHLD_REL_INC_POV': nan,
#  'PV_FIN_VULN': nan,
#  'WS_PPL_W-B': nan,
#  'WS_PPL_W-SM': 'Safely managed drinking water services (SDG 6.1.1)',
#  'WS_PPL_S-SM': 'Safely managed sanitation services (SDG 6.1.2)',
#  'WS_PPL_H-B': nan,
#  'HT_NO_BTH_SHW_FLSH': 'No bath, shower, or indoor flushing toilet in household',
#  'WS_PPL_S-OD': nan,
#  'EC_GII': 'Gender Inequality Index',
#  'EC_GDI': 'Gender Development Index ',
#  'HT_REG_CHLD_DISAB': nan,
#  'HT_REG_PS_DISAB': nan,
#  'HT_NEW_REG_CHLD_DISAB': nan,
#  'HT_NEW_REG_PS_DISAB': nan,
#  'HT_REG_CHLD_DISAB_PROP': 'Children registered as having disabilities',
#  'HT_NEW_REG_CHLD_DISAB_PROP': 'Children newly registered as having disabilities',
#  'SP_CHLD_DISAB_CASH': nan,
#  'SP_PS_DISAB_CASH': nan,
#  'CR_VC_VOV_GDSD_PD': nan,
#  'ECD_CHLD_24-59M_ADLT_SRC': 'Engagement in early stimulation activities with adult',
#  'ECD_CHLD_24-59M_FHR-SPT-LNG': 'Engagement in early stimulation activities with father',
#  'ECD_CHLD_36-59M_LMPSL': 'Early Childhood Development Index (SDG 4.2.1)',
#  'ECD_EARLY_EDU': 'Pupils from age 3 to the starting age of compulsory education at primary level',
#  'ECD_IN_CHILDCARE': 'Children in formal childcare',
#  'ECD_CHLD_U5_LFT-ALN': nan,
#  'CR_EG_EGY_CLEAN': 'Reliance on clean fuels and technology (SDG 7.1.2)',
#  'CR_EG_ACS_ELEC': nan,
#  'CR_CCRI': "Children's Climate Risk Index",
#  'CR_CCRI_EXP_CESS': 'CCRI Pillar 1',
#  'CR_CCRI_VUL_ES': 'CCRI Pillar 2',
#  'CR_SH_HAP_MORT': nan,
#  'CR_SH_STA_AIRP': nan,
#  'CR_SH_STA_ASAIRP': 'Mortailty rate - household and ambient air pollution  (SDG 3.9.1)',
#  'CR_SH_AAP_ASMORT': 'Mortailty rate - ambient air pollution (SDG 3.9.1)',
#  'CR_SH_HAP_ASMORT': 'Mortailty rate - household air pollution (SDG 3.9.1)',
#  'HT_SDG_PM25': 'Air quality (SDG 11.6.2)',
#  'CR_CCRI_VUL_WASH': nan,
#  'CR_CCRI_VUL_HT': nan,
#  'CR_CCRI_VUL_EDU': nan,
#  'CR_CCRI_VUL_SP': nan,
#  'CR_CCRI_EXP_WS': nan,
#  'CR_CCRI_EXP_RF': nan,
#  'CR_CCRI_EXP_CF': nan,
#  'CR_CCRI_EXP_TC': nan,
#  'CR_CCRI_EXP_VBD': nan,
#  'CR_CCRI_EXP_HEAT': nan,
#  'CR_CCRI_EXP_AP': nan,
#  'CR_CCRI_EXP_SWP': nan,
#  'CR_SH_AAP_MORT': nan,
#  'CR_AAP_DEATH': nan,
#  'CR_HAP_DEATH': nan,
#  'CR_VC_DSR_MTMP': 'Deaths and missing persons attributed to disasters (SDG 11.5.1)',
#  'CR_VC_DSR_DAFF': 'Persons directly affected by disasters (SDG 11.5.1)',
#  'CR_SG_DSR_LGRGSR': 'National DRR strategies (11.5.3)',
#  'DM_ASYL_FRST': 'First time asylum applicants',
#  'DM_ASYL_UASC': 'Unaccompanied minors',
#  'CR_INFORM': 'INFORM Risk Index',
#  'CR_INFORM_HA': nan,
#  'CR_INFORM_VU': nan,
#  'CR_INFORM_CC': nan,
#  'CR_INFORM_HA_NAT': nan,
#  'CR_INFORM_HA_HUM': nan,
#  'CR_INFORM_VU_SEV': nan,
#  'CR_INFORM_VU_VGR': nan,
#  'CR_INFORM_CC_INS': nan,
#  'CR_INFORM_CC_INF': nan,
#  'DM_SM_POP_REFG': nan,
#  'DM_SM_POP_REFG_OR': nan,
#  'NaN': nan}

# %%
graphs_dict = {
    "bar": {
        "options": dict(
            x="Country_name",
            y="OBS_VALUE",
            barmode="group",
            text="OBS_VALUE",
            custom_data=[
                "OBS_VALUE",
                "Country_name",
                "TIME_PERIOD",
                "OBS_FOOTNOTE",
                "DATA_SOURCE",
                "Sex_name",
                "Age_name",
                "Wealth_name",
                "Residence_name",
            ],
            height=500,
            text_auto=".3s",
        ),
        "layout_options": dict(
            xaxis_title={"standoff": 0},
            margin_t=30,
            margin_b=0,
        ),
    },
    "count_bar": {
        "options": dict(
            x="Status",
            color="Status",
            color_discrete_map={"Yes": "#1CABE2", "No": "#fcba03"},
            custom_data=[
                "OBS_VALUE",
                "Country_name",
                "TIME_PERIOD",
                "OBS_FOOTNOTE",
                "DATA_SOURCE",
                "Status",
            ],
            height=450,
            width=1000,
        ),
        "layout_options": dict(
            xaxis_title={"standoff": 0},
            margin_t=50,
            margin_b=0,
        ),
    },
    "line": {
        "options": dict(
            x="TIME_PERIOD",
            y="OBS_VALUE",
            color="Country_name",
            custom_data=[
                "OBS_VALUE",
                "Country_name",
                "TIME_PERIOD",
                "OBS_FOOTNOTE",
                "DATA_SOURCE",
            ],
            line_shape="spline",
            render_mode="svg",
            height=500,
        ),
        "trace_options": dict(mode="markers+lines", line=dict(width=0.8)),
        "layout_options": dict(
            xaxis_title={"standoff": 10},
            margin_t=40,
            margin_b=0,
        ),
    },
    "map": {
        "options": dict(
            locations="REF_AREA",
            featureidkey="id",
            color="OBS_VALUE",
            mapbox_style="carto-positron",
            #geojson=geo_json_countries,
            zoom=2.5,
            center={"lat": 51.9194, "lon": 19.040236},
            opacity=0.6,
            custom_data=[
                "OBS_VALUE",
                "Country_name",
                "TIME_PERIOD",
                "OBS_FOOTNOTE",
                "DATA_SOURCE",
            ],
            height=500,
            width=None,
        ),
        "layout_options": dict(margin={"r": 0, "t": 80, "l": 2, "b": 5}),
    },
}




min_max_card_suffix = "min - max values"

# %%
merged_page_config = {
    'child-rights': {
        'domain_name': 'Child Rights Landscape and Governance',
        'page_prefix': 'crg',
        'domain_colour': '#562061',
        'light_domain_colour': '#e7c9ed',
        'dark_domain_colour': '#44194d',
        'map_colour': 'purpor',
        'SUBDOMAINS': {
            'DEM': {
                'NAME': 'Demographics',
                'CARDS': [
                    {
                        'name': 'Child population (0-17 years)',
                        'indicator': 'DM_CHLD_POP',
                        'suffix': 'children',
                        'min_max': False,
                    },
                    {
                        'name': 'Percentage of children as a share of the total population',
                        'indicator': 'DM_CHLD_POP_PT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of births',
                        'indicator': 'DM_BRTS',
                        'suffix': 'births',
                        'min_max': False,
                    },
                    {
                        'name': 'Total fertility rate',
                        'indicator': 'DM_FRATE_TOT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Net migration',
                        'indicator': 'DM_POP_NETM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'DM_CHLD_POP',
                        'DM_CHLD_POP_PT',
                        'DM_BRTS',
                        'DM_FRATE_TOT',
                        'DM_POP_NETM',
                    ],
                    'default_graph': 'bar',
                    'default': 'DM_CHLD_POP',
                },
            },
            'PLE': {
                'NAME': 'Political economy',
                'CARDS': [
                    {
                        'name': 'Human Development Index',
                        'indicator': 'EC_HDI',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Total general government expenditure (% of GDP)',
                        'indicator': 'EC_TEC_GRL_GOV_EXP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'GDP per capita, PPP (current international $)',
                        'indicator': 'EC_NY_GDP_PCAP_PP_CD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'GNI per capita, Atlas method (current US$)',
                        'indicator': 'EC_NY_GNP_PCAP_CD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Gini coefficient of equivalised disposable income (Eurostat estimate)',
                        'indicator': 'PV_GINI_COEF',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Unemployment, modelled ILO estimate (% of total labour force) - SDG 8.5.2',
                        'indicator': 'EC_SL_UEM_TOTL_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Labour force participation rate',
                        'indicator': 'EC_EAP_RT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EC_HDI',
                        'EC_TEC_GRL_GOV_EXP',
                        'EC_NY_GDP_PCAP_PP_CD',
                        'EC_NY_GNP_PCAP_CD',
                        'PV_GINI_COEF',
                        'EC_SL_UEM_TOTL_ZS',
                        'EC_EAP_RT',
                    ],
                    'default_graph': 'bar',
                    'default': 'EC_HDI',
                },
            },
            'CRG': {
                'NAME': 'Child rights governance',
                'CARDS': [
                    {
                        'name': 'Countries with National Human Rights Institutions in compliance with the Paris Principles (A status) - SDG 16.a.1',
                        'indicator': 'PP_SG_NHR_IMPLN',
                        'suffix': 'countries in compliance with the Paris Principles',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PP_SG_NHR_IMPLN',
                    ],
                    'default_graph': 'map',
                    'default': 'PP_SG_NHR_IMPLN',
                },
            },
            'SPE': {
                'NAME': 'Public spending on children',
                'CARDS': [
                    {
                        'name': 'Government expenditure on education (% of GDP) (public spending sub-domain)',
                        'indicator': 'EDU_FIN_EXP_PT_GDP-SPE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Expenditure on pre-primary (% of government expenditure on education)',
                        'indicator': 'EDU_FIN_EXP_L02',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Expenditure on primary (% of government expenditure on education)',
                        'indicator': 'EDU_FIN_EXP_L1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Domestic general government health expenditure (% of GDP) (public spending sub-domain)',
                        'indicator': 'HT_SH_XPD_GHED_GD_ZS-SPE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Domestic general government health expenditure (% of GDP)',
                        'indicator': 'HT_SH_XPD_GHED_GD_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'General government expenditure by function: Social protection (% of GDP)',
                        'indicator': 'EC_SP_GOV_EXP_GDP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Expenditure on family-children benefits (% of expenditure on social benefits) (public spending sub-domain)',
                        'indicator': 'EC_EXP_FAM_CHLD_EXP-SPE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EDU_FIN_EXP_PT_GDP-SPE',
                        'EDU_FIN_EXP_L02',
                        'EDU_FIN_EXP_L1',
                        'HT_SH_XPD_GHED_GD_ZS-SPE',
                        'EC_SP_GOV_EXP_GDP',
                        'EC_EXP_FAM_CHLD_EXP-SPE',
                    ],
                    'default_graph': 'bar',
                    'default': 'EDU_FIN_EXP_PT_GDP-SPE',
                },
            },
            'DTA': {
                'NAME': 'Data on children',
                'CARDS': [
                    {
                        'name': 'Statistical capacity score',
                        'indicator': 'CR_IQ_SCI_OVRL',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Countries with national statistical legislation exists that complies with the Fundamental Principles of Official Statistics - SDG 17.18.2',
                        'indicator': 'CR_SG_STT_FPOS',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Value of all resources made available to strengthen statistical capacity in developing countries (current US$) - SDG 17.19.1',
                        'indicator': 'CR_SG_STT_CAPTY',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Countries with national statistical plans that are fully funded - SDG 17.18.3',
                        'indicator': 'CR_SG_STT_NSDSFND',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries with national statistical plans that are under implementation - SDG 17.18.3',
                        'indicator': 'CR_SG_STT_NSDSIMPL',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries with national statistical plans with funding from government - SDG 17.18.3',
                        'indicator': 'CR_SG_STT_NSDSFDGVT',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries with national statistical plans with funding from donors - SDG 17.18.3',
                        'indicator': 'CR_SG_STT_NSDSFDDNR',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries with national statistical plans with funding from others - SDG 17.18.3',
                        'indicator': 'CR_SG_STT_NSDSFDOTHR',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries that have conducted at least one population and housing census in the last 10 years - SDG 17.19.2',
                        'indicator': 'CR_SG_REG_CENSUSN',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'CR_IQ_SCI_OVRL',
                        'CR_SG_STT_FPOS',
                        'CR_SG_STT_CAPTY',
                        'CR_SG_STT_NSDSFND',
                        'CR_SG_STT_NSDSIMPL',
                        'CR_SG_STT_NSDSFDGVT',
                        'CR_SG_STT_NSDSFDDNR',
                        'CR_SG_STT_NSDSFDOTHR',
                        'CR_SG_REG_CENSUSN',
                    ],
                    'default_graph': 'map',
                    'default': 'CR_IQ_SCI_OVRL',
                },
            },
            'REM': {
                'NAME': 'Right to remedy',
                'CARDS': [
                    {
                        'name': 'Number of children (0-17 years) who brought or on whose behalf a complaint was brought by an adult to independent human rights mechanisms during the year',
                        'indicator': 'JJ_CHLD_COMPLAINT_HHRR',
                        'suffix': 'children',
                        'min_max': False,
                    },
                    {
                        'name': 'Number of children with disabilities (0-17 years) who brought or on whose behalf a complaint was brought by an adult to independent human rights mechanisms during the year',
                        'indicator': 'JJ_CHLD_DISAB_COMPLAINT_HHRR',
                        'suffix': 'children',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'JJ_CHLD_COMPLAINT_HHRR',
                        'JJ_CHLD_DISAB_COMPLAINT_HHRR',
                    ],
                    'default_graph': 'bar',
                    'default': 'JJ_CHLD_COMPLAINT_HHRR',
                },
            },
        },
    },
    'child-health': {
        'domain_name': 'Health and Nutrition',
        'page_prefix': 'han',
        'domain_colour': '#3e7c49',
        'light_domain_colour': '#e0f0e3',
        'dark_domain_colour': '#24472a',
        'map_colour': 'algae',
        'SUBDOMAINS': {
            'HSM': {
                'NAME': 'Health system',
                'CARDS': [
                    {
                        'name': 'UHC Service Coverage Index - SDG 3.8.1',
                        'indicator': 'HT_UHC_IDX',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Current health expenditure (% of GDP)',
                        'indicator': 'HT_SH_XPD_CHEX_GD_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Domestic general government health expenditure (% of GDP) (health system sub-domain)',
                        'indicator': 'HT_SH_XPD_GHED_GD_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Domestic general government health expenditure (% of general government expenditure)',
                        'indicator': 'HT_SH_XPD_GHED_GE_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Domestic general government health expenditure per capita, PPP (current international $)',
                        'indicator': 'HT_SH_XPD_GHED_PP_CD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Out-of-pocket expenditure (% of current health expenditure)',
                        'indicator': 'HT_SH_XPD_OOPC_CH_ZS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Total population covered by public and primary private health insurance',
                        'indicator': 'HT_INS_COV',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'HT_UHC_IDX',
                        'HT_SH_XPD_CHEX_GD_ZS',
                        'HT_SH_XPD_GHED_GD_ZS',
                        'HT_SH_XPD_GHED_GE_ZS',
                        'HT_SH_XPD_GHED_PP_CD',
                        'HT_SH_XPD_OOPC_CH_ZS',
                        'HT_INS_COV',
                    ],
                    'default_graph': 'bar',
                    'default': 'HT_UHC_IDX',
                },
            },
            'MNH': {
                'NAME': 'Maternal, newborn and child health',
                'CARDS': [
                    {
                        'name': 'Neonatal mortality rate - SDG 3.2.2 (child health sub-domain)',
                        'indicator': 'CME_MRM0',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Infant mortality rate - SDG 3.2.1',
                        'indicator': 'CME_MRY0',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Under-five mortality rate - SDG 3.2.1',
                        'indicator': 'CME_MRY0T4',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of births attended by skilled health personnel - SDG 3.1.2',
                        'indicator': 'MNCH_SAB',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Stillbirth rate',
                        'indicator': 'CME_SBR',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'C-section rate - percentage of deliveries by caesarean section',
                        'indicator': 'MNCH_CSEC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Prevalence of low birth weight among newborns',
                        'indicator': 'NT_BW_LBW',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'CME_MRM0',
                        'CME_MRY0',
                        'CME_MRY0T4',
                        'MNCH_SAB',
                        'CME_SBR',
                        'MNCH_CSEC',
                        'NT_BW_LBW',
                    ],
                    'default_graph': 'bar',
                    'default': 'CME_MRM0',
                },
            },
            'IMM': {
                'NAME': 'Immunization',
                'CARDS': [
                    {
                        'name': 'Percentage of children who received the 2nd dose of measles-containing vaccine (MCV2) - SDG 3.b.1',
                        'indicator': 'IM_MCV2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of surviving infants who received the third dose of DTP-containing vaccine (DTP3) - SDG 3.b.1',
                        'indicator': 'IM_DTP3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of surviving infants who received the third dose of pneumococcal conjugate-containing vaccine (PCV3) - SDG 3.b.1',
                        'indicator': 'IM_PCV3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of females who received the last dose of human papillomavirus (HPV) vaccine per national schedule - SDG 3.b.1',
                        'indicator': 'IM_HPV',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'IM_MCV2',
                        'IM_DTP3',
                        'IM_PCV3',
                        'IM_HPV',
                    ],
                    'default_graph': 'bar',
                    'default': 'IM_MCV2',
                },
            },
            'NUT': {
                'NAME': 'Nutrition',
                'CARDS': [
                    {
                        'name': 'Percentage of infants (under 6 months) who are exclusively breastfed (nutrition sub-domain)',
                        'indicator': 'NT_BF_EXBF',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children born in the last 24 months who were put to the breast within one hour of birth',
                        'indicator': 'NT_BF_EIBF',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Introduction to solid, semi-solid foods (6-8 months)',
                        'indicator': 'NT_CF_ISSSF_FL',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Minimum Acceptable Diet (6-23 months)',
                        'indicator': 'NT_CF_MAD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Overweight prevalence (weight-for-height >+2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
                        'indicator': 'NT_ANT_WHZ_PO2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Obesity prevalence among children and adolescents (5-19 years)',
                        'indicator': 'NT_CHLD_OBESITY',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Wasting prevalence (weight-for-height <-2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
                        'indicator': 'NT_ANT_WHZ_NE2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Stunting prevalence (height-for-age <-2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
                        'indicator': 'NT_ANT_HAZ_NE2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of women (15-49 years) with anaemia - SDG 2.2.3',
                        'indicator': 'HT_SH_STA_ANEM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Prevalence of anaemia in children (6–59 months)',
                        'indicator': 'HT_ANEM_U5',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'NT_BF_EXBF',
                        'NT_BF_EIBF',
                        'NT_CF_ISSSF_FL',
                        'NT_CF_MAD',
                        'NT_ANT_WHZ_PO2',
                        'NT_CHLD_OBESITY',
                        'NT_ANT_WHZ_NE2',
                        'NT_ANT_HAZ_NE2',
                        'HT_SH_STA_ANEM',
                        'HT_ANEM_U5',
                    ],
                    'default_graph': 'bar',
                    'default': 'NT_BF_EXBF',
                },
            },
            'ADO': {
                'NAME': 'Adolescent physical, mental and reproductive health',
                'CARDS': [
                    {
                        'name': 'Adolescent birth rate - SDG 3.7.2 (adolescent health sub-domain)',
                        'indicator': 'FT_SP_DYN_ADKL',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Adolescent mortality rate',
                        'indicator': 'HT_ADOL_MT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Suicide mortality rate - SDG 3.4.2 (adolescent health sub-domain)',
                        'indicator': 'MT_SDG_SUICIDE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of 15-year-old students who report doing the WHO-recommended duration of daily exercise',
                        'indicator': 'HT_CHLD_DAILY_EXER',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'FT_SP_DYN_ADKL',
                        'HT_ADOL_MT',
                        'MT_SDG_SUICIDE',
                        'HT_CHLD_DAILY_EXER',
                    ],
                    'default_graph': 'bar',
                    'default': 'FT_SP_DYN_ADKL',
                },
            },
            'HIV': {
                'NAME': 'HIV/AIDS',
                'CARDS': [
                    {
                        'name': 'Estimated number of children  (0-19 years) living with HIV',
                        'indicator': 'HVA_EPI_LHIV_0-19',
                        'suffix': 'estimated children living with HIV',
                        'min_max': False,
                    },
                    {
                        'name': 'Estimated incidence rate among children (0-14 years) - SDG 3.3.1',
                        'indicator': 'HVA_EPI_INF_RT_0-14',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Estimated number of annual AIDS-related deaths among children (0-19 years)',
                        'indicator': 'HVA_EPI_DTH_ANN_0-19',
                        'suffix': 'estimated AIDS-related deaths',
                        'min_max': False,
                    },
                    {
                        'name': 'Mother-to-child HIV transmission rate',
                        'indicator': 'HVA_PMTCT_MTCT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of pregnant women presenting at antenatal clinics who were tested for HIV or already knew their HIV positive status',
                        'indicator': 'HVA_PMTCT_STAT_CVG',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (0-14 years) living with HIV and receiving antiretroviral therapy',
                        'indicator': 'HVA_PED_ART_CVG',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'HVA_EPI_LHIV_0-19',
                        'HVA_EPI_INF_RT_0-14',
                        'HVA_EPI_DTH_ANN_0-19',
                        'HVA_PMTCT_MTCT',
                        'HVA_PMTCT_STAT_CVG',
                        'HVA_PED_ART_CVG',
                    ],
                    'default_graph': 'bar',
                    'default': 'HVA_EPI_LHIV_0-19',
                },
            },
        },
    },
    'child-education': {
        'domain_name': 'Education, Leisure and Culture',
        'page_prefix': 'edu',
        'domain_colour': '#37568f',
        'light_domain_colour': '#bdcbe5',
        'dark_domain_colour': '#1d2c49',
        'map_colour': 'ice_r',
        'SUBDOMAINS': {
            'ESY': {
                'NAME': 'Education system',
                'CARDS': [
                    {
                        'name': 'Government expenditure on education (% of GDP) (education system sub-domain)',
                        'indicator': 'EDU_FIN_EXP_PT_GDP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of years of free pre-primary education guaranteed in legal framework',
                        'indicator': 'EDU_SDG_FREE_EDU_L02',
                        'suffix': 'countries guaranteeing at least one year',
                        'min_max': False,
                    },
                    {
                        'name': 'Number of years of compulsory pre-primary education guaranteed in legal framework',
                        'indicator': 'EDU_SDG_COMP_EDU_L02',
                        'suffix': 'countries guaranteeing at least one year',
                        'min_max': False,
                    },
                    {
                        'name': 'Administration of nationally-representative learning assessment in math (end of primary education)',
                        'indicator': 'EDUNF_ADMIN_L1_GLAST_MAT',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Administration of nationally-representative learning assessment in reading (end of primary education)',
                        'indicator': 'EDUNF_ADMIN_L1_GLAST_REA',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Administration of nationally-representative learning assessment in math (end of lower secondary education)',
                        'indicator': 'EDUNF_ADMIN_L2_MAT',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Administration of nationally-representative learning assessment in reading (end of lower secondary education)',
                        'indicator': 'EDUNF_ADMIN_L2_REA',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EDU_FIN_EXP_PT_GDP',
                        'EDUNF_ADMIN_L1_GLAST_MAT',
                        'EDUNF_ADMIN_L1_GLAST_REA',
                        'EDUNF_ADMIN_L2_MAT',
                        'EDUNF_ADMIN_L2_REA',
                        'EDU_SDG_FREE_EDU_L02',
                        'EDU_SDG_COMP_EDU_L02',
                    ],
                    'default_graph': 'bar',
                    'default': 'EDU_FIN_EXP_PT_GDP',
                },
            },
            'EPA': {
                'NAME': 'Education access and participation',
                'CARDS': [
                    {
                        'name': 'Primary education completion rate - SDG 4.1.2',
                        'indicator': 'EDUNF_CR_L1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Lower secondary education completion rate - SDG 4.1.2',
                        'indicator': 'EDUNF_CR_L2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Upper secondary education completion rate - SDG 4.1.2 (education access sub-domain)',
                        'indicator': 'EDUNF_CR_L3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Out-of-school rate for children one year younger than the official entry age to primary education',
                        'indicator': 'EDUNF_ROFST_L1_UNDER1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Out-of-school rate for children of primary school age',
                        'indicator': 'EDUNF_ROFST_L1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Out-of-school rate for adolescents of lower secondary school age',
                        'indicator': 'EDUNF_ROFST_L2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Out-of-school rate for youth of upper secondary school age',
                        'indicator': 'EDUNF_ROFST_L3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Participation in organized learning (adjusted net enrolment rate, one year before official primary entry age - administrative data) - SDG 4.2.2 (education access sub-domain)',
                        'indicator': 'EDUNF_NERA_L1_UNDER1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Pupils from age 3 to the starting age of compulsory education at primary level (education access sub-domain)',
                        'indicator': 'ECD_EARLY_EDU',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of primary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (education access sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L1',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of lower secondary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (education access sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L2',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of upper secondary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (education access sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of early leavers from education and training',
                        'indicator': 'EDAT_LFSE_14',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Participation rate of youth and adults in formal and non-formal education and training - SDG 4.3.1',
                        'indicator': 'EDU_SDG_PRYA',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EDUNF_CR_L1',
                        'EDUNF_CR_L2',
                        'EDUNF_CR_L3',
                        'EDUNF_ROFST_L1_UNDER1',
                        'EDUNF_ROFST_L1',
                        'EDUNF_ROFST_L2',
                        'EDUNF_ROFST_L3',
                        'EDUNF_NERA_L1_UNDER1',
                        'ECD_EARLY_EDU',
                        'EDU_SDG_SCH_L1',
                        'EDU_SDG_SCH_L2',
                        'EDU_SDG_SCH_L3',
                        'EDAT_LFSE_14',
                        'EDU_SDG_PRYA',
                    ],
                    'default_graph': 'bar',
                    'default': 'EDUNF_CR_L1',
                },
            },
            'EQU': {
                'NAME': 'Learning quality and skills',
                'CARDS': [
                    {
                        'name': 'Percentage of 15-year-olds achieving low scores in mathematics',
                        'indicator': 'EDU_PISA_LOW_ACHIEVE_MAT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of 15-year-olds achieving low scores in reading',
                        'indicator': 'EDU_PISA_LOW_ACHIEVE_REA',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of 15-year-olds achieving low scores in science',
                        'indicator': 'EDU_PISA_LOW_ACHIEVE_SCI',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in math - SDG 4.1.1 (learning sub-domain)',
                        'indicator': 'EDU_SDG_STU_L2_GLAST_MAT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in reading - SDG 4.1.1 (learning sub-domain)',
                        'indicator': 'EDU_SDG_STU_L2_GLAST_REA',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of youth (15-24 years) not in education, employment or training - SDG 8.6.1 (learning sub-domain)',
                        'indicator': 'EDU_SDG_YOUTH_NEET',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EDU_PISA_LOW_ACHIEVE_MAT',
                        'EDU_PISA_LOW_ACHIEVE_REA',
                        'EDU_PISA_LOW_ACHIEVE_SCI',
                        'EDU_SDG_STU_L2_GLAST_MAT',
                        'EDU_SDG_STU_L2_GLAST_REA',
                        'EDU_SDG_YOUTH_NEET',
                    ],
                    'default_graph': 'bar',
                    'default': 'EDU_PISA_LOW_ACHIEVE_MAT',
                },
            },
            'ELE': {
                'NAME': 'Leisure and culture',
                'CARDS': [
                    {
                        'name': 'Percentage of 15-year-old students who watch TV or play video games, before or after school',
                        'indicator': 'PP_ADOL_TVGM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of 15-year-old students who use the internet and social networks, before or after school',
                        'indicator': 'PP_ADOL_INET',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PP_ADOL_TVGM',
                        'PP_ADOL_INET',
                    ],
                    'default_graph': 'bar',
                    'default': 'PP_ADOL_TVGM',
                },
            },
        },
    },
    'child-protection': {
        'domain_name': 'Family Environment and Protection',
        'page_prefix': 'chp',
        'domain_colour': '#e5ae4c',
        'light_domain_colour': '#f4daaf',
        'dark_domain_colour': '#9c6b16',
        'map_colour': 'YlOrBr',
        'SUBDOMAINS': {
            'VIO': {
                'NAME': 'Violence against children and women',
                'CARDS': [
                    {
                        'name': 'Percentage of children (1-14 years) who experienced any physical punishment and/or psychological aggression by caregivers - SDG 16.2.1 (violence sub-domain)',
                        'indicator': 'PT_CHLD_1-14_PS-PSY-V_CGVR',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of adults who think that physical punishment is necessary to raise/educate children',
                        'indicator': 'PT_ADLT_PS_NEC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of ever-partnered women and girls (15 years and older) subjected to physical, sexual or psychological violence by a current or former intimate partner in the previous 12 months - SDG 5.2.1 (violence sub-domain)',
                        'indicator': 'PT_F_GE15_PS-SX-EM_V_PTNR_12MNTH',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of women (18-29 years) who experienced sexual violence by age 18 years - SDG 16.2.3',
                        'indicator': 'PT_F_18-29_SX-V_AGE-18',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of students (13-15 years) who reported being bullied on 1 or more days in the past 30 days',
                        'indicator': 'PT_ST_13-15_BUL_30-DYS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of child victims of violence (0-17 years) registered by child/social welfare authorities during the year',
                        'indicator': 'PT_CHLD_VIOLENCE_WELFARE',
                        'suffix': 'child victims of violence',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PT_CHLD_1-14_PS-PSY-V_CGVR',
                        'PT_ADLT_PS_NEC',
                        'PT_F_GE15_PS-SX-EM_V_PTNR_12MNTH',
                        'PT_F_18-29_SX-V_AGE-18',
                        'PT_ST_13-15_BUL_30-DYS',
                        'PT_CHLD_VIOLENCE_WELFARE',
                    ],
                    'default_graph': 'bar',
                    'default': 'PT_CHLD_1-14_PS-PSY-V_CGVR',
                },
            },
            'CPC': {
                'NAME': 'Children in alternative care',
                'CARDS': [
                    {
                        'name': 'Rate of children (0-17 years) in formal alternative care at the end of the year (per 100,000)',
                        'indicator': 'PT_CHLD_INFORMALCARE_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of children (0-17 years) in formal residential care at the end of the year (per 100,000)',
                        'indicator': 'PT_CHLD_INRESIDENTIAL_RATE_B',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of children (0-17 years) in formal family-based care at the end of the year (per 100,000)',
                        'indicator': 'PT_CHLD_INCARE_FOSTER_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of formal adoption of children (0-17 years) during the year (per 100,000)',
                        'indicator': 'PT_CHLD_ADOPTION_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PT_CHLD_INFORMALCARE_RATE',
                        'PT_CHLD_INRESIDENTIAL_RATE_B',
                        'PT_CHLD_INCARE_FOSTER_RATE',
                        'PT_CHLD_ADOPTION_RATE',
                    ],
                    'default_graph': 'bar',
                    'default': 'PT_CHLD_INFORMALCARE_RATE',
                },
            },
            'JUS': {
                'NAME': 'Justice for children',
                'CARDS': [
                    {
                        'name': 'Rate of children (0-17 years) in detention at the end of the year (per 100,000)',
                        'indicator': 'JJ_CHLD_DETENTION_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of children (0-17 years) in pre-sentence detention at the end of the year (per 100,000)',
                        'indicator': 'JJ_CHLD_PRE_SENTENCE_DETENTION_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of children (0-17 years) in post-sentence detention at the end of the year (per 100,000)',
                        'indicator': 'JJ_CHLD_POST_SENTENCE_DETENTION_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of children (0-17 years) detained in pre-sentence detention during the year (per 100,000)',
                        'indicator': 'JJ_CHLD_ENTER_PRE_SENTENCE_DETENTION_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (0-17 years) sentenced to custodial sentences during the year',
                        'indicator': 'JJ_CHLD_CUSTODIAL_SENTENCE_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (0-17 years) sentenced with alternative measures during the year',
                        'indicator': 'JJ_CHLD_ALTERNATIVE_SENTENCE_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of child victims of crime (0-17 years) registered by the police during the year (per 100,000)',
                        'indicator': 'JJ_CHLD_VICTIM_CRIME_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Rate of child witnesses of crime (0-17 years) registered by the police during the year (per 100,000)',
                        'indicator': 'JJ_CHLD_WITNESS_CRIME_RATE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Unsentenced detainees as a proportion of overall prison population - SDG 16.3.2',
                        'indicator': 'JJ_VC_PRS_UNSNT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'JJ_CHLD_DETENTION_RATE',
                        'JJ_CHLD_PRE_SENTENCE_DETENTION_RATE',
                        'JJ_CHLD_POST_SENTENCE_DETENTION_RATE',
                        'JJ_CHLD_ENTER_PRE_SENTENCE_DETENTION_RATE',
                        'JJ_CHLD_CUSTODIAL_SENTENCE_PROP',
                        'JJ_CHLD_ALTERNATIVE_SENTENCE_PROP',
                        'JJ_CHLD_VICTIM_CRIME_RATE',
                        'JJ_CHLD_WITNESS_CRIME_RATE',
                        'JJ_VC_PRS_UNSNT',
                    ],
                    'default_graph': 'bar',
                    'default': 'JJ_CHLD_DETENTION_RATE',
                },
            },
            'MAR': {
                'NAME': 'Child marriage and other harmful practices',
                'CARDS': [
                    {
                        'name': 'Percentage of women (20-24 years) married or in union before age 18 - SDG 5.3.1 (child marriage sub-domain)',
                        'indicator': 'PT_F_20-24_MRD_U18',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of men (20-24 years) married or in union before age 18',
                        'indicator': 'PT_M_20-24_MRD_U18',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of girls (15-19 years) who are currently married or in union (child marriage sub-domain)',
                        'indicator': 'PT_F_15-19_MRD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of boys (15-19 years) who are currently married or in union',
                        'indicator': 'PT_M_15-19_MRD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PT_F_20-24_MRD_U18',
                        'PT_M_20-24_MRD_U18',
                        'PT_F_15-19_MRD',
                        'PT_M_15-19_MRD',
                    ],
                    'default_graph': 'bar',
                    'default': 'PT_F_20-24_MRD_U18',
                },
            },
            'LAB': {
                'NAME': 'Child exploitation',
                'CARDS': [
                    {
                        'name': 'Percentage of children (5-17 years) engaged in child labour (economic activities and household chores) - SDG 8.7.1',
                        'indicator': 'PT_CHLD_5-17_LBR_ECON-HC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (5-17 years) engaged in child labour (economic activities)',
                        'indicator': 'PT_CHLD_5-17_LBR_ECON',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PT_CHLD_5-17_LBR_ECON-HC',
                        'PT_CHLD_5-17_LBR_ECON',
                    ],
                    'default_graph': 'bar',
                    'default': 'PT_CHLD_5-17_LBR_ECON-HC',
                },
            },
        },
    },
    'child-participation': {
        'domain_name': 'Participation and Civil Rights',
        'page_prefix': 'par',
        'domain_colour': '#861c3f',
        'light_domain_colour': '#eca7be',
        'dark_domain_colour': '#541228',
        'map_colour': 'Brwnyl',
        'SUBDOMAINS': {
            'REG': {
                'NAME': 'Birth registration and identity',
                'CARDS': [
                    {
                        'name': 'Percentage of children whose births have been registered with a civil authority - SDG 16.9.1',
                        'indicator': 'PT_CHLD_Y0T4_REG',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Countries with birth registration data that are at least 90 percent complete - SDG 17.19.2',
                        'indicator': 'PP_SG_REG_BRTH90N',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                    {
                        'name': 'Countries with death registration data that are at least 75 percent complete - SDG 17.19.2',
                        'indicator': 'PP_SG_REG_DETH75N',
                        'suffix': 'countries',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PT_CHLD_Y0T4_REG',
                        'PP_SG_REG_BRTH90N',
                        'PP_SG_REG_DETH75N',
                    ],
                    'default_graph': 'bar',
                    'default': 'PT_CHLD_Y0T4_REG',
                },
            },
            'ICT': {
                'NAME': 'Information, internet and protection of privacy',
                'CARDS': [
                    {
                        'name': 'Internet users per 100 inhabitants - SDG 17.8.1',
                        'indicator': 'PP_IT_USE_ii99',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of youth and adults with ICT skill: writing a computer program using a specialized programming language - SDG 4.4.1',
                        'indicator': 'PP_SE_ADT_ACTS_PRGM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of youth and adults with ICT skill: sending e-mails with attached files - SDG 4.4.1',
                        'indicator': 'PP_SE_ADT_ACTS_ATCH',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of youth and adults with ICT skill: finding, downloading, installing and configuring software - SDG 4.4.1',
                        'indicator': 'PP_SE_ADT_ACTS_SFWR',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population who used the internet in the last 3 months and managed access to their personal data (information sub-domain)',
                        'indicator': 'ICT_PERSONAL_DATA',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population who limited their personal internet activities in the last 12 months due to security concerns',
                        'indicator': 'ICT_SECURITY_CONCERN',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PP_IT_USE_ii99',
                        'PP_SE_ADT_ACTS_PRGM',
                        'PP_SE_ADT_ACTS_ATCH',
                        'PP_SE_ADT_ACTS_SFWR',
                        'ICT_PERSONAL_DATA',
                        'ICT_SECURITY_CONCERN',
                    ],
                    'default_graph': 'bar',
                    'default': 'PP_IT_USE_ii99',
                },
            },
        },
    },
    'child-poverty': {
        'domain_name': 'Poverty and Social Protection',
        'page_prefix': 'pov',
        'domain_colour': '#4c8cbb',
        'light_domain_colour': '#c0d7e7',
        'dark_domain_colour': '#1c374a',
        'map_colour': 'GnBu',
        'SUBDOMAINS': {
            'SPS': {
                'NAME': 'Social protection system',
                'CARDS': [
                    {
                        'name': 'Percentage of population covered by at least one social protection benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_BENFTS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children/households receiving child/family cash benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_CHLD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of mothers with newborns receiving maternity cash benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_MATNL',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population with severe disabilities receiving disability cash benefit - SDG 1.3.1 (social protection sub-domain)',
                        'indicator': 'PV_SI_COV_DISAB',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of unemployed persons receiving unemployment cash benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_UEMP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of vulnerable population receiving social assistance cash benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_VULN',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of poor population receiving social assistance cash benefit - SDG 1.3.1',
                        'indicator': 'PV_SI_COV_POOR',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Expenditure on family-children benefits (% of expenditure on social benefits) (social protection sub-domain)',
                        'indicator': 'EC_EXP_FAM_CHLD_EXP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'PV_SI_COV_BENFTS',
                        'PV_SI_COV_CHLD',
                        'PV_SI_COV_MATNL',
                        'PV_SI_COV_DISAB',
                        'PV_SI_COV_UEMP',
                        'PV_SI_COV_VULN',
                        'PV_SI_COV_POOR',
                        'EC_EXP_FAM_CHLD_EXP',
                    ],
                    'default_graph': 'bar',
                    'default': 'PV_SI_COV_BENFTS',
                },
            },
            'MAT': {
                'NAME': 'Child poverty and material deprivation',
                'CARDS': [
                    {
                        'name': 'Poverty headcount ratio at $6.85 a day (2017 PPP)',
                        'indicator': 'SI_POV_UMIC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population living below the national poverty line - SDG 1.2.1',
                        'indicator': 'PV_SDG_SI_POV_NAHC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'People at risk of poverty or social exclusion',
                        'indicator': 'PV_AROPE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Severe material and social deprivation rate',
                        'indicator': 'PV_SEV_MAT_SOC_DPRT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'At-risk-of-poverty rate by threshold: 60% of national median equivalized disposable income after social transfers',
                        'indicator': 'PV_AROPRT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'People living in households with very low work intensity',
                        'indicator': 'PV_LOW_WORK',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Share of households with dependent children with inability to afford a meal with protein every second day',
                        'indicator': 'PV_INABLE_PROTEIN',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'SI_POV_UMIC',
                        'PV_SDG_SI_POV_NAHC',
                        'PV_AROPE',
                        'PV_SEV_MAT_SOC_DPRT',
                        'PV_AROPRT',
                        'PV_LOW_WORK',
                        'PV_INABLE_PROTEIN',
                    ],
                    'default_graph': 'bar',
                    'default': 'SI_POV_UMIC',
                },
            },
            'WSH': {
                'NAME': 'Water and sanitation',
                'CARDS': [
                    {
                        'name': 'Percentage of population using safely managed drinking water services - SDG 6.1.1',
                        'indicator': 'WS_PPL_W-SM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population using safely managed sanitation services - SDG 6.2.1',
                        'indicator': 'WS_PPL_S-SM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population having neither a bath, nor a shower, nor indoor flushing toilet in their household',
                        'indicator': 'HT_NO_BTH_SHW_FLSH',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'WS_PPL_W-SM',
                        'WS_PPL_S-SM',
                        'HT_NO_BTH_SHW_FLSH',
                    ],
                    'default_graph': 'bar',
                    'default': 'WS_PPL_W-SM',
                },
            },
        },
    },
    'child-cross-cutting': {
        'domain_name': 'Cross-Cutting',
        'page_prefix': 'cci',
        'domain_colour': '#ec5e24',
        'light_domain_colour': '#f4d5c0',
        'dark_domain_colour': '#903717',
        'map_colour': 'Oranges',
        'SUBDOMAINS': {
            'GND': {
                'NAME': 'Gender',
                'CARDS': [
                    {
                        'name': 'Gender Development Index',
                        'indicator': 'EC_GDI',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Gender Inequality Index',
                        'indicator': 'EC_GII',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Adolescent birth rate - SDG 3.7.2 (gender sub-domain)',
                        'indicator': 'FT_SP_DYN_ADKL-GND',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Adjusted gender parity index for upper secondary education completion rate - SDG 4.5.1',
                        'indicator': 'EDU_SE_AGP_CPRA_L3',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Adjusted gender parity index for students at the end of lower secondary education achieving a minimum proficiency level in mathematics - SDG 4.5.1',
                        'indicator': 'EDU_SE_TOT_GPI_L2_MAT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Adjusted gender parity index for students at the end of lower secondary education achieving a minimum proficiency level in reading - SDG 4.5.1',
                        'indicator': 'EDU_SE_TOT_GPI_L2_REA',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (1-14 years) who experienced any physical punishment and/or psychological aggression by caregivers - SDG 16.2.1 (gender sub-domain)',
                        'indicator': 'PT_CHLD_1-14_PS-PSY-V_CGVR-GND',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of ever-partnered women and girls (15 years and older) subjected to physical, sexual or psychological violence by a current or former intimate partner in the previous 12 months - SDG 5.2.1 (gender sub-domain)',
                        'indicator': 'PT_F_GE15_PS-SX-EM_V_PTNR_12MNTH-GND',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of girls (15-19 years) who are currently married or in union (gender sub-domain)',
                        'indicator': 'PT_F_15-19_MRD-GND',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of women (20-24 years) married or in union before age 18 - SDG 5.3.1. (gender sub-domain)',
                        'indicator': 'PT_F_20-24_MRD_U18-GND',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'EC_GDI',
                        'EC_GII',
                        'FT_SP_DYN_ADKL-GND',
                        'EDU_SE_AGP_CPRA_L3',
                        'EDU_SE_TOT_GPI_L2_MAT',
                        'EDU_SE_TOT_GPI_L2_REA-GND',
                        'PT_CHLD_1-14_PS-PSY-V_CGVR-GND',
                        'PT_F_GE15_PS-SX-EM_V_PTNR_12MNTH-GND',
                        'PT_F_15-19_MRD-GND',
                        'PT_F_20-24_MRD_U18-GND',
                    ],
                    'default_graph': 'bar',
                    'default': 'EC_GDI-GND',
                },
            },
            'DIS': {
                'NAME': 'Disability',
                'CARDS': [
                    {
                        'name': 'Percentage of children (0-17 years) registered as having disabilities at the end of the year',
                        'indicator': 'HT_REG_CHLD_DISAB_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (0-17 years) newly registered as having disabilities during the year',
                        'indicator': 'HT_NEW_REG_CHLD_DISAB_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of primary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (disability sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L1-DIS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of lower secondary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (disability sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L2-DIS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of upper secondary schools with access to adapted infrastructure and materials for students with disabilities - SDG 4.a.1 (disability sub-domain)',
                        'indicator': 'EDU_SDG_SCH_L3-DIS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children with disabilities (0-17 years) in formal residential care at the end of the year',
                        'indicator': 'PT_CHLD_DISAB_INRESIDENTIAL_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children with disabilities (0-17 years) in formal family-based care at the end of the year',
                        'indicator': 'PT_CHLD_DISAB_INFAMILY_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children with disabilities (0-17 years) in formal foster care of the total number of children in formal family-based care at the end of the year',
                        'indicator': 'PT_CHLD_DISAB_INFOSTER_PROP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population with severe disabilities receiving disability cash benefit - SDG 1.3.1 (disability sub-domain)',
                        'indicator': 'PV_SI_COV_DISAB',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'HT_REG_CHLD_DISAB_PROP',
                        'HT_NEW_REG_CHLD_DISAB_PROP',
                        'EDU_SDG_SCH_L1-DIS',
                        'EDU_SDG_SCH_L2-DIS',
                        'EDU_SDG_SCH_L3-DIS',
                        'PT_CHLD_DISAB_INRESIDENTIAL_PROP',
                        'PT_CHLD_DISAB_INFAMILY_PROP',
                        'PT_CHLD_DISAB_INFOSTER_PROP',
                        'PV_SI_COV_DISAB-DIS',
                    ],
                    'default_graph': 'bar',
                    'default': 'HT_REG_CHLD_DISAB_PROP',
                },
            },
            'ECD': {
                'NAME': 'Early childhood development',
                'CARDS': [
                    {
                        'name': '4.2.1. Percentage of children (36-59 months) developmentally on track in at least 3 of the 4 following domains: literacy-numeracy, physical, social-emotional and learning',
                        'indicator': 'ECD_CHLD_36-59M_LMPSL',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Neonatal mortality rate - SDG 3.2.2 (ECD sub-domain)',
                        'indicator': 'CME_MRM0-ECD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of infants (under 6 months) who are exclusively breastfed (ECD sub-domain)',
                        'indicator': 'NT_BF_EXBF-ECD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of children (36-59 months) with whom any adult household member has engaged in 4 or more activities to provide early stimulation and responsive care in the last 3 days',
                        'indicator': 'ECD_CHLD_24-59M_ADLT_SRC',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Participation in organized learning (adjusted net enrolment rate, one year before official primary entry age - administrative data) - SDG 4.2.2 (ECD sub-domain)',
                        'indicator': 'EDUNF_NERA_L1_UNDER1-ECD',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Children aged less than 3 years in formal childcare',
                        'indicator': 'ECD_IN_CHILDCARE',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Pupils from age 3 to the starting age of compulsory education at primary level (ECD sub-domain)',
                        'indicator': 'ECD_EARLY_EDU',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'ECD_CHLD_36-59M_LMPSL',
                        'CME_MRM0-ECD',
                        'NT_BF_EXBF-ECD',
                        'ECD_CHLD_24-59M_ADLT_SRC',
                        'EDUNF_NERA_L1_UNDER1-ECD',
                        'ECD_IN_CHILDCARE',
                        'ECD_EARLY_EDU-ECD',
                    ],
                    'default_graph': 'bar',
                    'default': 'ECD_CHLD_36-59M_LMPSL',
                },
            },
            "ODA": {
                "NAME": "Adolescents",
                "CARDS": [
                    {
                        'name': 'Adolescent birth rate - SDG 3.7.2 (adolescents sub-domain)',
                        'indicator': 'FT_SP_DYN_ADKL-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Suicide mortality rate - SDG 3.4.2 (adolescents sub-domain)',
                        'indicator': 'MT_SDG_SUICIDE-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Percentage of youth (15-24 years) not in education, employment or training - SDG 8.6.1 (adolescents sub-domain)',
                        'indicator': 'EDU_SDG_YOUTH_NEET-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in math - SDG 4.1.1 (adolescents sub-domain)',
                        'indicator': 'EDU_SDG_STU_L2_GLAST_MAT-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in reading - SDG 4.1.1 (adolescents sub-domain)',
                        'indicator': 'EDU_SDG_STU_L2_GLAST_REA-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Upper secondary education completion rate - SDG 4.1.2 (adolescents sub-domain)',
                        'indicator': 'EDUNF_CR_L3-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Percentage of children (1-14 years) who experienced any physical punishment and/or psychological aggression by caregivers - SDG 16.2.1 (adolescents sub-domain)',
                        'indicator': 'PT_CHLD_1-14_PS-PSY-V_CGVR-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                    {
                        'name': 'Percentage of population who used the internet in the last 3 months and managed access to their personal data (adolescents sub-domain)',
                        'indicator': 'ICT_PERSONAL_DATA-ADO',
                        "suffix": min_max_card_suffix,
                        "min_max": True,
                    },
                ],
                "AIO_AREA": {
                    "graphs": graphs_dict,
                    "indicators": [
                        "FT_SP_DYN_ADKL-ADO",
                        "MT_SDG_SUICIDE-ADO",
                        "EDU_SDG_YOUTH_NEET-ADO",
                        "EDU_SDG_STU_L2_GLAST_MAT-ADO",
                        "EDU_SDG_STU_L2_GLAST_REA-ADO",
                        "EDUNF_CR_L3-ADO",
                        "PT_CHLD_1-14_PS-PSY-V_CGVR-ADO",
                        "ICT_PERSONAL_DATA-ADO",
                    ],
                    "default_graph": "bar",
                    "default": "FT_SP_DYN_ADKL-ADO",
                },
            },
            'ENV': {
                'NAME': 'Environment and climate change',
                'CARDS': [
                    {
                        'name': "Children's Climate Risk Index (CCRI)",
                        'indicator': 'CR_CCRI',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': "CCRI Pillar 1: Children's exposure to climate and environmental hazards, shocks and stresses",
                        'indicator': 'CR_CCRI_EXP_CESS',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': "CCRI Pillar 2: Children's vulnerability to climate and environmental hazards, shocks and stresses",
                        'indicator': 'CR_CCRI_VUL_ES',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Percentage of population with primary reliance on clean fuels and technology - SDG 7.1.2',
                        'indicator': 'CR_EG_EGY_CLEAN',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Age-standardized mortality rate attributed to household and ambient air pollution - SDG 3.9.1',
                        'indicator': 'CR_SH_STA_ASAIRP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Age-standardized mortality rate attributed to household air pollution - SDG 3.9.1',
                        'indicator': 'CR_SH_HAP_ASMORT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Age-standardized mortality rate attributed to ambient air pollution - SDG 3.9.1',
                        'indicator': 'CR_SH_AAP_ASMORT',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Annual mean concentration of particles PM2.5 (ug/m3) - SDG 11.6.2',
                        'indicator': 'HT_SDG_PM25',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'CR_CCRI',
                        'CR_CCRI_EXP_CESS',
                        'CR_CCRI_VUL_ES',
                        'CR_EG_EGY_CLEAN',
                        'CR_SH_STA_ASAIRP',
                        'CR_SH_HAP_ASMORT',
                        'CR_SH_AAP_ASMORT',
                        'HT_SDG_PM25',
                    ],
                    'default_graph': 'bar',
                    'default': 'CR_CCRI',
                },
            },
            'DCD': {
                'NAME': 'Disaster, conflict and displacement',
                'CARDS': [
                    {
                        'name': 'INFORM Risk Index',
                        'indicator': 'CR_INFORM',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of deaths and missing persons attributed to disasters (per 100,000 population) - SDG 11.5.1',
                        'indicator': 'CR_VC_DSR_MTMP',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of directly affected persons attributed to disasters (per 100,000 population) - SDG 11.5.1',
                        'indicator': 'CR_VC_DSR_DAFF',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Score of adoption and implementation of national DRR strategies in line with the Sendai Framework - SDG 1.5.3',
                        'indicator': 'CR_SG_DSR_LGRGSR',
                        'suffix': min_max_card_suffix,
                        'min_max': True,
                    },
                    {
                        'name': 'Number of first time asylum applicants',
                        'indicator': 'DM_ASYL_FRST',
                        'suffix': 'persons',
                        'min_max': False,
                    },
                    {
                        'name': 'Number of asylum applicants considered to be unaccompanied minors',
                        'indicator': 'DM_ASYL_UASC',
                        'suffix': 'persons',
                        'min_max': False,
                    },
                ],
                'AIO_AREA': {
                    'graphs': graphs_dict,
                    'indicators': [
                        'CR_INFORM',
                        'CR_VC_DSR_MTMP',
                        'CR_VC_DSR_DAFF',
                        'CR_SG_DSR_LGRGSR',
                        'DM_ASYL_FRST',
                        'DM_ASYL_UASC',
                    ],
                    'default_graph': 'bar',
                    'default': 'CR_INFORM',
                },
            },
        },
    },
}

# %%
# Function to add button names to the merged_page_config
def add_button_names_to_config(config, buttons):
    for domain in config.values():
        for subdomain in domain['SUBDOMAINS'].values():
            for card in subdomain['CARDS']:
                indicator_code = card['indicator']
                button_name = buttons.get(indicator_code)
                if button_name:
                    card['button_name'] = button_name
    return config

# Update the merged_page_config with button names
updated_merged_page_config = add_button_names_to_config(merged_page_config, indicator_buttons)

# Display a portion of the updated config for verification
updated_merged_page_config['child-rights']['SUBDOMAINS']['DEM']['CARDS'][:2] # Displaying first two cards for demo
# Out:
# [{'name': 'Child population (0-17 years)',
#   'indicator': 'DM_CHLD_POP',
#   'suffix': 'children',
#   'min_max': False,
#   'button_name': 'Child population'},
#  {'name': 'Percentage of children as a share of the total population',
#   'indicator': 'DM_CHLD_POP_PT',
#   'suffix': 'min - max values',
#   'min_max': True,
#   'button_name': 'Children as a share of the total population'}]

# %%
updated_merged_page_config
# Out:
# {'child-rights': {'domain_name': 'Child Rights Landscape and Governance',
#   'page_prefix': 'crg',
#   'domain_colour': '#562061',
#   'light_domain_colour': '#e7c9ed',
#   'dark_domain_colour': '#44194d',
#   'map_colour': 'purpor',
#   'SUBDOMAINS': {'DEM': {'NAME': 'Demographics',
#     'CARDS': [{'name': 'Child population (0-17 years)',
#       'indicator': 'DM_CHLD_POP',
#       'suffix': 'children',
#       'min_max': False,
#       'button_name': 'Child population'},
#      {'name': 'Percentage of children as a share of the total population',
#       'indicator': 'DM_CHLD_POP_PT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Children as a share of the total population'},
#      {'name': 'Number of births',
#       'indicator': 'DM_BRTS',
#       'suffix': 'births',
#       'min_max': False,
#       'button_name': 'Number of births'},
#      {'name': 'Total fertility rate',
#       'indicator': 'DM_FRATE_TOT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Total fertility rate'},
#      {'name': 'Net migration',
#       'indicator': 'DM_POP_NETM',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Net migration'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['DM_CHLD_POP',
#       'DM_CHLD_POP_PT',
#       'DM_BRTS',
#       'DM_FRATE_TOT',
#       'DM_POP_NETM'],
#      'default_graph': 'bar',
#      'default': 'DM_CHLD_POP'}},
#    'PLE': {'NAME': 'Political economy',
#     'CARDS': [{'name': 'Human Development Index',
#       'indicator': 'EC_HDI',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Human Development Index'},
#      {'name': 'Total general government expenditure (% of GDP)',
#       'indicator': 'EC_TEC_GRL_GOV_EXP',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Total general government expenditure'},
#      {'name': 'GDP per capita, PPP (current international $)',
#       'indicator': 'EC_NY_GDP_PCAP_PP_CD',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'GDP per capita, PPP'},
#      {'name': 'GNI per capita, Atlas method (current US$)',
#       'indicator': 'EC_NY_GNP_PCAP_CD',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'GNI per capita, Atlas method'},
#      {'name': 'Gini coefficient of equivalised disposable income (Eurostat estimate)',
#       'indicator': 'PV_GINI_COEF',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Gini Index'},
#      {'name': 'Unemployment, modelled ILO estimate (% of total labour force) - SDG 8.5.2',
#       'indicator': 'EC_SL_UEM_TOTL_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Unemployment, modelled ILO estimate (SDG 8.5.2)'},
#      {'name': 'Labour force participation rate',
#       'indicator': 'EC_EAP_RT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Labour force participation rate'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['EC_HDI',
#       'EC_TEC_GRL_GOV_EXP',
#       'EC_NY_GDP_PCAP_PP_CD',
#       'EC_NY_GNP_PCAP_CD',
#       'PV_GINI_COEF',
#       'EC_SL_UEM_TOTL_ZS',
#       'EC_EAP_RT'],
#      'default_graph': 'bar',
#      'default': 'EC_HDI'}},
#    'CRG': {'NAME': 'Child rights governance',
#     'CARDS': [{'name': 'Countries with National Human Rights Institutions in compliance with the Paris Principles (A status) - SDG 16.a.1',
#       'indicator': 'PP_SG_NHR_IMPLN',
#       'suffix': 'countries in compliance with the Paris Principles',
#       'min_max': False,
#       'button_name': 'Status of National Human Rights Institutions (SDG 16.a.1)'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['PP_SG_NHR_IMPLN'],
#      'default_graph': 'map',
#      'default': 'PP_SG_NHR_IMPLN'}},
#    'SPE': {'NAME': 'Public spending on children',
#     'CARDS': [{'name': 'Government expenditure on education (% of GDP) (public spending sub-domain)',
#       'indicator': 'EDU_FIN_EXP_PT_GDP-SPE',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Expenditure on pre-primary (% of government expenditure on education)',
#       'indicator': 'EDU_FIN_EXP_L02',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Expenditure on pre-primary education'},
#      {'name': 'Expenditure on primary (% of government expenditure on education)',
#       'indicator': 'EDU_FIN_EXP_L1',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Expenditure on primary education'},
#      {'name': 'Domestic general government health expenditure (% of GDP) (public spending sub-domain)',
#       'indicator': 'HT_SH_XPD_GHED_GD_ZS-SPE',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Domestic general government health expenditure (% of GDP)',
#       'indicator': 'HT_SH_XPD_GHED_GD_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Domestic general government health expenditure'},
#      {'name': 'General government expenditure by function: Social protection (% of GDP)',
#       'indicator': 'EC_SP_GOV_EXP_GDP',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'General government expenditure on social protection'},
#      {'name': 'Expenditure on family-children benefits (% of expenditure on social benefits) (public spending sub-domain)',
#       'indicator': 'EC_EXP_FAM_CHLD_EXP-SPE',
#       'suffix': 'min - max values',
#       'min_max': True}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['EDU_FIN_EXP_PT_GDP-SPE',
#       'EDU_FIN_EXP_L02',
#       'EDU_FIN_EXP_L1',
#       'HT_SH_XPD_GHED_GD_ZS-SPE',
#       'EC_SP_GOV_EXP_GDP',
#       'EC_EXP_FAM_CHLD_EXP-SPE'],
#      'default_graph': 'bar',
#      'default': 'EDU_FIN_EXP_PT_GDP-SPE'}},
#    'DTA': {'NAME': 'Data on children',
#     'CARDS': [{'name': 'Statistical capacity score',
#       'indicator': 'CR_IQ_SCI_OVRL',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Statistical capacity score'},
#      {'name': 'Countries with national statistical legislation exists that complies with the Fundamental Principles of Official Statistics - SDG 17.18.2',
#       'indicator': 'CR_SG_STT_FPOS',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Compliance of national statistical legislation (SDG 17.18.2)'},
#      {'name': 'Value of all resources made available to strengthen statistical capacity in developing countries (current US$) - SDG 17.19.1',
#       'indicator': 'CR_SG_STT_CAPTY',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Value of resources to strengthen statistical capacity (SDG 17.19.1)'},
#      {'name': 'Countries with national statistical plans that are fully funded - SDG 17.18.3',
#       'indicator': 'CR_SG_STT_NSDSFND',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'National statistical plans that are fully funded (SDG 17.18.3)'},
#      {'name': 'Countries with national statistical plans that are under implementation - SDG 17.18.3',
#       'indicator': 'CR_SG_STT_NSDSIMPL',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'National statistical plans that are under implementation (SDG 17.18.3)'},
#      {'name': 'Countries with national statistical plans with funding from government - SDG 17.18.3',
#       'indicator': 'CR_SG_STT_NSDSFDGVT',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'National statistical plans with funding from government (SDG 17.18.3)'},
#      {'name': 'Countries with national statistical plans with funding from donors - SDG 17.18.3',
#       'indicator': 'CR_SG_STT_NSDSFDDNR',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'National statistical plans with funding from donors (SDG 17.18.3)'},
#      {'name': 'Countries with national statistical plans with funding from others - SDG 17.18.3',
#       'indicator': 'CR_SG_STT_NSDSFDOTHR',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'National statistical plans with funding from others (SDG 17.18.3)'},
#      {'name': 'Countries that have conducted at least one population and housing census in the last 10 years - SDG 17.19.2',
#       'indicator': 'CR_SG_REG_CENSUSN',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Census'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['CR_IQ_SCI_OVRL',
#       'CR_SG_STT_FPOS',
#       'CR_SG_STT_CAPTY',
#       'CR_SG_STT_NSDSFND',
#       'CR_SG_STT_NSDSIMPL',
#       'CR_SG_STT_NSDSFDGVT',
#       'CR_SG_STT_NSDSFDDNR',
#       'CR_SG_STT_NSDSFDOTHR',
#       'CR_SG_REG_CENSUSN'],
#      'default_graph': 'map',
#      'default': 'CR_IQ_SCI_OVRL'}},
#    'REM': {'NAME': 'Right to remedy',
#     'CARDS': [{'name': 'Number of children (0-17 years) who brought or on whose behalf a complaint was brought by an adult to independent human rights mechanisms during the year',
#       'indicator': 'JJ_CHLD_COMPLAINT_HHRR',
#       'suffix': 'children',
#       'min_max': False,
#       'button_name': 'Number of children who lodged a complaint a human rights complaint during the year'},
#      {'name': 'Number of children with disabilities (0-17 years) who brought or on whose behalf a complaint was brought by an adult to independent human rights mechanisms during the year',
#       'indicator': 'JJ_CHLD_DISAB_COMPLAINT_HHRR',
#       'suffix': 'children',
#       'min_max': False,
#       'button_name': 'Number of children with disabilities who lodged a complaint a human rights complaint during the year'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['JJ_CHLD_COMPLAINT_HHRR', 'JJ_CHLD_DISAB_COMPLAINT_HHRR'],
#      'default_graph': 'bar',
#      'default': 'JJ_CHLD_COMPLAINT_HHRR'}}}},
#  'child-health': {'domain_name': 'Health and Nutrition',
#   'page_prefix': 'han',
#   'domain_colour': '#3e7c49',
#   'light_domain_colour': '#e0f0e3',
#   'dark_domain_colour': '#24472a',
#   'map_colour': 'algae',
#   'SUBDOMAINS': {'HSM': {'NAME': 'Health system',
#     'CARDS': [{'name': 'UHC Service Coverage Index - SDG 3.8.1',
#       'indicator': 'HT_UHC_IDX',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'UHC Service Coverage Index (SDG 3.8.1)'},
#      {'name': 'Current health expenditure (% of GDP)',
#       'indicator': 'HT_SH_XPD_CHEX_GD_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Current health expenditure'},
#      {'name': 'Domestic general government health expenditure (% of GDP) (health system sub-domain)',
#       'indicator': 'HT_SH_XPD_GHED_GD_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Domestic general government health expenditure'},
#      {'name': 'Domestic general government health expenditure (% of general government expenditure)',
#       'indicator': 'HT_SH_XPD_GHED_GE_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Domestic general government health expenditure (% of general government expenditure)'},
#      {'name': 'Domestic general government health expenditure per capita, PPP (current international $)',
#       'indicator': 'HT_SH_XPD_GHED_PP_CD',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Domestic general government health expenditure per capita'},
#      {'name': 'Out-of-pocket expenditure (% of current health expenditure)',
#       'indicator': 'HT_SH_XPD_OOPC_CH_ZS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Out-of-pocket expenditure'},
#      {'name': 'Total population covered by public and primary private health insurance',
#       'indicator': 'HT_INS_COV',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Population covered by health insurance '}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['HT_UHC_IDX',
#       'HT_SH_XPD_CHEX_GD_ZS',
#       'HT_SH_XPD_GHED_GD_ZS',
#       'HT_SH_XPD_GHED_GE_ZS',
#       'HT_SH_XPD_GHED_PP_CD',
#       'HT_SH_XPD_OOPC_CH_ZS',
#       'HT_INS_COV'],
#      'default_graph': 'bar',
#      'default': 'HT_UHC_IDX'}},
#    'MNH': {'NAME': 'Maternal, newborn and child health',
#     'CARDS': [{'name': 'Neonatal mortality rate - SDG 3.2.2 (child health sub-domain)',
#       'indicator': 'CME_MRM0',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Neonatal mortality rate (SDG 3.2.2)'},
#      {'name': 'Infant mortality rate - SDG 3.2.1',
#       'indicator': 'CME_MRY0',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Infant mortality rate'},
#      {'name': 'Under-five mortality rate - SDG 3.2.1',
#       'indicator': 'CME_MRY0T4',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Under-five mortality rate (SDG 3.2.1)'},
#      {'name': 'Percentage of births attended by skilled health personnel - SDG 3.1.2',
#       'indicator': 'MNCH_SAB',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Births attended by skilled health personnel (SDG 3.1.2)'},
#      {'name': 'Stillbirth rate',
#       'indicator': 'CME_SBR',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Stillbirth rate'},
#      {'name': 'C-section rate - percentage of deliveries by caesarean section',
#       'indicator': 'MNCH_CSEC',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'C-section rate'},
#      {'name': 'Prevalence of low birth weight among newborns',
#       'indicator': 'NT_BW_LBW',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Low birth weight among newborns'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['CME_MRM0',
#       'CME_MRY0',
#       'CME_MRY0T4',
#       'MNCH_SAB',
#       'CME_SBR',
#       'MNCH_CSEC',
#       'NT_BW_LBW'],
#      'default_graph': 'bar',
#      'default': 'CME_MRM0'}},
#    'IMM': {'NAME': 'Immunization',
#     'CARDS': [{'name': 'Percentage of children who received the 2nd dose of measles-containing vaccine (MCV2) - SDG 3.b.1',
#       'indicator': 'IM_MCV2',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'MCV2 coverage (SDG 3.b.1)'},
#      {'name': 'Percentage of surviving infants who received the third dose of DTP-containing vaccine (DTP3) - SDG 3.b.1',
#       'indicator': 'IM_DTP3',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'DTP3 coverage (SDG 3.b.1)'},
#      {'name': 'Percentage of surviving infants who received the third dose of pneumococcal conjugate-containing vaccine (PCV3) - SDG 3.b.1',
#       'indicator': 'IM_PCV3',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'PCV3 coverage (SDG 3.b.1)'},
#      {'name': 'Percentage of females who received the last dose of human papillomavirus (HPV) vaccine per national schedule - SDG 3.b.1',
#       'indicator': 'IM_HPV',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'HPV coverage (SDG 3.b.1)'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['IM_MCV2', 'IM_DTP3', 'IM_PCV3', 'IM_HPV'],
#      'default_graph': 'bar',
#      'default': 'IM_MCV2'}},
#    'NUT': {'NAME': 'Nutrition',
#     'CARDS': [{'name': 'Percentage of infants (under 6 months) who are exclusively breastfed (nutrition sub-domain)',
#       'indicator': 'NT_BF_EXBF',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Exclusive breastfeeding'},
#      {'name': 'Percentage of children born in the last 24 months who were put to the breast within one hour of birth',
#       'indicator': 'NT_BF_EIBF',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Early initiation of breastfeeding'},
#      {'name': 'Introduction to solid, semi-solid foods (6-8 months)',
#       'indicator': 'NT_CF_ISSSF_FL',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Introduction to solid, semi-solid foods'},
#      {'name': 'Minimum Acceptable Diet (6-23 months)',
#       'indicator': 'NT_CF_MAD',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Minimum acceptable diet'},
#      {'name': 'Overweight prevalence (weight-for-height >+2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
#       'indicator': 'NT_ANT_WHZ_PO2',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Prevalence of overweight (SDG 2.2.2)'},
#      {'name': 'Obesity prevalence among children and adolescents (5-19 years)',
#       'indicator': 'NT_CHLD_OBESITY',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Prevalence of obesity'},
#      {'name': 'Wasting prevalence (weight-for-height <-2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
#       'indicator': 'NT_ANT_WHZ_NE2',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Prevalence of wasting'},
#      {'name': 'Stunting prevalence (height-for-age <-2 standard deviations from the median of the WHO Child Growth Standards) among children under 5 years of age - SDG 2.2.2',
#       'indicator': 'NT_ANT_HAZ_NE2',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Prevalence of stunting (SDG 2.2.1 )'},
#      {'name': 'Percentage of women (15-49 years) with anaemia - SDG 2.2.3',
#       'indicator': 'HT_SH_STA_ANEM',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Anaemia among women (SDG 2.2.3 )'},
#      {'name': 'Prevalence of anaemia in children (6–59 months)',
#       'indicator': 'HT_ANEM_U5',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Anaemia among children under 5 years'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['NT_BF_EXBF',
#       'NT_BF_EIBF',
#       'NT_CF_ISSSF_FL',
#       'NT_CF_MAD',
#       'NT_ANT_WHZ_PO2',
#       'NT_CHLD_OBESITY',
#       'NT_ANT_WHZ_NE2',
#       'NT_ANT_HAZ_NE2',
#       'HT_SH_STA_ANEM',
#       'HT_ANEM_U5'],
#      'default_graph': 'bar',
#      'default': 'NT_BF_EXBF'}},
#    'ADO': {'NAME': 'Adolescent physical, mental and reproductive health',
#     'CARDS': [{'name': 'Adolescent birth rate - SDG 3.7.2 (adolescent health sub-domain)',
#       'indicator': 'FT_SP_DYN_ADKL',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Adolescent birth rate (SDG 3.7.2)'},
#      {'name': 'Adolescent mortality rate',
#       'indicator': 'HT_ADOL_MT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Adolescent mortality rate'},
#      {'name': 'Suicide mortality rate - SDG 3.4.2 (adolescent health sub-domain)',
#       'indicator': 'MT_SDG_SUICIDE',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Suicide rate (SDG 3.4.2)'},
#      {'name': 'Percentage of 15-year-old students who report doing the WHO-recommended duration of daily exercise',
#       'indicator': 'HT_CHLD_DAILY_EXER',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'WHO-recommended daily exercise'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['FT_SP_DYN_ADKL',
#       'HT_ADOL_MT',
#       'MT_SDG_SUICIDE',
#       'HT_CHLD_DAILY_EXER'],
#      'default_graph': 'bar',
#      'default': 'FT_SP_DYN_ADKL'}},
#    'HIV': {'NAME': 'HIV/AIDS',
#     'CARDS': [{'name': 'Estimated number of children  (0-19 years) living with HIV',
#       'indicator': 'HVA_EPI_LHIV_0-19',
#       'suffix': 'estimated children living with HIV',
#       'min_max': False,
#       'button_name': 'Children living with HIV'},
#      {'name': 'Estimated incidence rate among children (0-14 years) - SDG 3.3.1',
#       'indicator': 'HVA_EPI_INF_RT_0-14',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'New HIV infections (SDG 3.3.1) '},
#      {'name': 'Estimated number of annual AIDS-related deaths among children (0-19 years)',
#       'indicator': 'HVA_EPI_DTH_ANN_0-19',
#       'suffix': 'estimated AIDS-related deaths',
#       'min_max': False,
#       'button_name': 'Annual AIDS-related deaths'},
#      {'name': 'Mother-to-child HIV transmission rate',
#       'indicator': 'HVA_PMTCT_MTCT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Mother-to-child HIV transmission rate'},
#      {'name': 'Percentage of pregnant women presenting at antenatal clinics who were tested for HIV or already knew their HIV positive status',
#       'indicator': 'HVA_PMTCT_STAT_CVG',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Pregnant women and HIV testing'},
#      {'name': 'Percentage of children (0-14 years) living with HIV and receiving antiretroviral therapy',
#       'indicator': 'HVA_PED_ART_CVG',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Children receiving ART'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['HVA_EPI_LHIV_0-19',
#       'HVA_EPI_INF_RT_0-14',
#       'HVA_EPI_DTH_ANN_0-19',
#       'HVA_PMTCT_MTCT',
#       'HVA_PMTCT_STAT_CVG',
#       'HVA_PED_ART_CVG'],
#      'default_graph': 'bar',
#      'default': 'HVA_EPI_LHIV_0-19'}}}},
#  'child-education': {'domain_name': 'Education, Leisure and Culture',
#   'page_prefix': 'edu',
#   'domain_colour': '#37568f',
#   'light_domain_colour': '#bdcbe5',
#   'dark_domain_colour': '#1d2c49',
#   'map_colour': 'ice_r',
#   'SUBDOMAINS': {'ESY': {'NAME': 'Education system',
#     'CARDS': [{'name': 'Government expenditure on education (% of GDP) (education system sub-domain)',
#       'indicator': 'EDU_FIN_EXP_PT_GDP',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Government expenditure on education'},
#      {'name': 'Number of years of free pre-primary education guaranteed in legal framework',
#       'indicator': 'EDU_SDG_FREE_EDU_L02',
#       'suffix': 'countries guaranteeing at least one year',
#       'min_max': False,
#       'button_name': 'Years of free pre-primary education'},
#      {'name': 'Number of years of compulsory pre-primary education guaranteed in legal framework',
#       'indicator': 'EDU_SDG_COMP_EDU_L02',
#       'suffix': 'countries guaranteeing at least one year',
#       'min_max': False,
#       'button_name': 'Years of compulsory pre-primary education'},
#      {'name': 'Administration of nationally-representative learning assessment in math (end of primary education)',
#       'indicator': 'EDUNF_ADMIN_L1_GLAST_MAT',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Learning assessments in math (end of primary education)'},
#      {'name': 'Administration of nationally-representative learning assessment in reading (end of primary education)',
#       'indicator': 'EDUNF_ADMIN_L1_GLAST_REA',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Learning assessments in reading (end of primary education)'},
#      {'name': 'Administration of nationally-representative learning assessment in math (end of lower secondary education)',
#       'indicator': 'EDUNF_ADMIN_L2_MAT',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Learning assessments in math (end of lower secondary education)'},
#      {'name': 'Administration of nationally-representative learning assessment in reading (end of lower secondary education)',
#       'indicator': 'EDUNF_ADMIN_L2_REA',
#       'suffix': 'countries',
#       'min_max': False,
#       'button_name': 'Learning assessments in reading (end of lower secondary education)'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
# ...
#       'indicator': 'NT_BF_EXBF-ECD',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of children (36-59 months) with whom any adult household member has engaged in 4 or more activities to provide early stimulation and responsive care in the last 3 days',
#       'indicator': 'ECD_CHLD_24-59M_ADLT_SRC',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Engagement in early stimulation activities with adult'},
#      {'name': 'Participation in organized learning (adjusted net enrolment rate, one year before official primary entry age - administrative data) - SDG 4.2.2 (ECD sub-domain)',
#       'indicator': 'EDUNF_NERA_L1_UNDER1-ECD',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Children aged less than 3 years in formal childcare',
#       'indicator': 'ECD_IN_CHILDCARE',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Children in formal childcare'},
#      {'name': 'Pupils from age 3 to the starting age of compulsory education at primary level (ECD sub-domain)',
#       'indicator': 'ECD_EARLY_EDU',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Pupils from age 3 to the starting age of compulsory education at primary level'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['ECD_CHLD_36-59M_LMPSL',
#       'CME_MRM0-ECD',
#       'NT_BF_EXBF-ECD',
#       'ECD_CHLD_24-59M_ADLT_SRC',
#       'EDUNF_NERA_L1_UNDER1-ECD',
#       'ECD_IN_CHILDCARE',
#       'ECD_EARLY_EDU-ECD'],
#      'default_graph': 'bar',
#      'default': 'ECD_CHLD_36-59M_LMPSL'}},
#    'ODA': {'NAME': 'Adolescents',
#     'CARDS': [{'name': 'Adolescent birth rate - SDG 3.7.2 (adolescents sub-domain)',
#       'indicator': 'FT_SP_DYN_ADKL-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Suicide mortality rate - SDG 3.4.2 (adolescents sub-domain)',
#       'indicator': 'MT_SDG_SUICIDE-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of youth (15-24 years) not in education, employment or training - SDG 8.6.1 (adolescents sub-domain)',
#       'indicator': 'EDU_SDG_YOUTH_NEET-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in math - SDG 4.1.1 (adolescents sub-domain)',
#       'indicator': 'EDU_SDG_STU_L2_GLAST_MAT-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of children at the end of lower secondary education reaching minimum proficiency in reading - SDG 4.1.1 (adolescents sub-domain)',
#       'indicator': 'EDU_SDG_STU_L2_GLAST_REA-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Upper secondary education completion rate - SDG 4.1.2 (adolescents sub-domain)',
#       'indicator': 'EDUNF_CR_L3-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of children (1-14 years) who experienced any physical punishment and/or psychological aggression by caregivers - SDG 16.2.1 (adolescents sub-domain)',
#       'indicator': 'PT_CHLD_1-14_PS-PSY-V_CGVR-ADO',
#       'suffix': 'min - max values',
#       'min_max': True},
#      {'name': 'Percentage of population who used the internet in the last 3 months and managed access to their personal data (adolescents sub-domain)',
#       'indicator': 'ICT_PERSONAL_DATA-ADO',
#       'suffix': 'min - max values',
#       'min_max': True}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['FT_SP_DYN_ADKL-ADO',
#       'MT_SDG_SUICIDE-ADO',
#       'EDU_SDG_YOUTH_NEET-ADO',
#       'EDU_SDG_STU_L2_GLAST_MAT-ADO',
#       'EDU_SDG_STU_L2_GLAST_REA-ADO',
#       'EDUNF_CR_L3-ADO',
#       'PT_CHLD_1-14_PS-PSY-V_CGVR-ADO',
#       'ICT_PERSONAL_DATA-ADO'],
#      'default_graph': 'bar',
#      'default': 'FT_SP_DYN_ADKL-ADO'}},
#    'ENV': {'NAME': 'Environment and climate change',
#     'CARDS': [{'name': "Children's Climate Risk Index (CCRI)",
#       'indicator': 'CR_CCRI',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': "Children's Climate Risk Index"},
#      {'name': "CCRI Pillar 1: Children's exposure to climate and environmental hazards, shocks and stresses",
#       'indicator': 'CR_CCRI_EXP_CESS',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'CCRI Pillar 1'},
#      {'name': "CCRI Pillar 2: Children's vulnerability to climate and environmental hazards, shocks and stresses",
#       'indicator': 'CR_CCRI_VUL_ES',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'CCRI Pillar 2'},
#      {'name': 'Percentage of population with primary reliance on clean fuels and technology - SDG 7.1.2',
#       'indicator': 'CR_EG_EGY_CLEAN',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Reliance on clean fuels and technology (SDG 7.1.2)'},
#      {'name': 'Age-standardized mortality rate attributed to household and ambient air pollution - SDG 3.9.1',
#       'indicator': 'CR_SH_STA_ASAIRP',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Mortailty rate - household and ambient air pollution  (SDG 3.9.1)'},
#      {'name': 'Age-standardized mortality rate attributed to household air pollution - SDG 3.9.1',
#       'indicator': 'CR_SH_HAP_ASMORT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Mortailty rate - household air pollution (SDG 3.9.1)'},
#      {'name': 'Age-standardized mortality rate attributed to ambient air pollution - SDG 3.9.1',
#       'indicator': 'CR_SH_AAP_ASMORT',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Mortailty rate - ambient air pollution (SDG 3.9.1)'},
#      {'name': 'Annual mean concentration of particles PM2.5 (ug/m3) - SDG 11.6.2',
#       'indicator': 'HT_SDG_PM25',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Air quality (SDG 11.6.2)'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['CR_CCRI',
#       'CR_CCRI_EXP_CESS',
#       'CR_CCRI_VUL_ES',
#       'CR_EG_EGY_CLEAN',
#       'CR_SH_STA_ASAIRP',
#       'CR_SH_HAP_ASMORT',
#       'CR_SH_AAP_ASMORT',
#       'HT_SDG_PM25'],
#      'default_graph': 'bar',
#      'default': 'CR_CCRI'}},
#    'DCD': {'NAME': 'Disaster, conflict and displacement',
#     'CARDS': [{'name': 'INFORM Risk Index',
#       'indicator': 'CR_INFORM',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'INFORM Risk Index'},
#      {'name': 'Number of deaths and missing persons attributed to disasters (per 100,000 population) - SDG 11.5.1',
#       'indicator': 'CR_VC_DSR_MTMP',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Deaths and missing persons attributed to disasters (SDG 11.5.1)'},
#      {'name': 'Number of directly affected persons attributed to disasters (per 100,000 population) - SDG 11.5.1',
#       'indicator': 'CR_VC_DSR_DAFF',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'Persons directly affected by disasters (SDG 11.5.1)'},
#      {'name': 'Score of adoption and implementation of national DRR strategies in line with the Sendai Framework - SDG 1.5.3',
#       'indicator': 'CR_SG_DSR_LGRGSR',
#       'suffix': 'min - max values',
#       'min_max': True,
#       'button_name': 'National DRR strategies (11.5.3)'},
#      {'name': 'Number of first time asylum applicants',
#       'indicator': 'DM_ASYL_FRST',
#       'suffix': 'persons',
#       'min_max': False,
#       'button_name': 'First time asylum applicants'},
#      {'name': 'Number of asylum applicants considered to be unaccompanied minors',
#       'indicator': 'DM_ASYL_UASC',
#       'suffix': 'persons',
#       'min_max': False,
#       'button_name': 'Unaccompanied minors'}],
#     'AIO_AREA': {'graphs': {'bar': {'options': {'x': 'Country_name',
#         'y': 'OBS_VALUE',
#         'barmode': 'group',
#         'text': 'OBS_VALUE',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Sex_name',
#          'Age_name',
#          'Wealth_name',
#          'Residence_name'],
#         'height': 500,
#         'text_auto': '.3s'},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 30,
#         'margin_b': 0}},
#       'count_bar': {'options': {'x': 'Status',
#         'color': 'Status',
#         'color_discrete_map': {'Yes': '#1CABE2', 'No': '#fcba03'},
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE',
#          'Status'],
#         'height': 450,
#         'width': 1000},
#        'layout_options': {'xaxis_title': {'standoff': 0},
#         'margin_t': 50,
#         'margin_b': 0}},
#       'line': {'options': {'x': 'TIME_PERIOD',
#         'y': 'OBS_VALUE',
#         'color': 'Country_name',
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'line_shape': 'spline',
#         'render_mode': 'svg',
#         'height': 500},
#        'trace_options': {'mode': 'markers+lines', 'line': {'width': 0.8}},
#        'layout_options': {'xaxis_title': {'standoff': 10},
#         'margin_t': 40,
#         'margin_b': 0}},
#       'map': {'options': {'locations': 'REF_AREA',
#         'featureidkey': 'id',
#         'color': 'OBS_VALUE',
#         'mapbox_style': 'carto-positron',
#         'zoom': 2.5,
#         'center': {'lat': 51.9194, 'lon': 19.040236},
#         'opacity': 0.6,
#         'custom_data': ['OBS_VALUE',
#          'Country_name',
#          'TIME_PERIOD',
#          'OBS_FOOTNOTE',
#          'DATA_SOURCE'],
#         'height': 500,
#         'width': None},
#        'layout_options': {'margin': {'r': 0, 't': 80, 'l': 2, 'b': 5}}}},
#      'indicators': ['CR_INFORM',
#       'CR_VC_DSR_MTMP',
#       'CR_VC_DSR_DAFF',
#       'CR_SG_DSR_LGRGSR',
#       'DM_ASYL_FRST',
#       'DM_ASYL_UASC'],
#      'default_graph': 'bar',
#      'default': 'CR_INFORM'}}}}}
